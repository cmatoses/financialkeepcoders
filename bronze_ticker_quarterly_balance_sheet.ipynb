# %%
from datetime import datetime
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud import bigquery
from google.cloud.exceptions import NotFound
import pandas as pd
import yahoo_fin.stock_info as si
from utils.utils_bigquery import *
from datetime import *
import json

# %%
key_path = key_path
project = project_id

# Sources
table = 'silver_indicators'
dataset = 'silver'

# Tables id
table_conca = f'{project}.{dataset}.{table}'

# Loading tables
table_to_save = 'bronze_ticker_quarterly_balance_sheet'
dataset_to_save = 'bronze'

# %%
# Conectamos con Bigquery
bigquery = BigQueryUtils(key_path)

# %%
tickers = bigquery.run_query(
    f"""
    SELECT DISTINCT
        ticker
    FROM {project}.{dataset}.{table}
    """
)
tickers
# Out:
#      ticker
# 0      PCAR
# 1      EQIX
# 2       CNC
# 3       ARE
# 4      EBAY
# ...     ...
# 3440   ZEUS
# 3441    ELF
# 3442   MMSI
# 3443   SGBX
# 3444   BLUE
#
# [3445 rows x 1 columns]

# %%
import yfinance as yf
import pandas as pd

data = []

for _, row in tickers.iterrows():
    ticker = row['ticker']  # Corregir el nombre de la columna para acceder al ticker

    try:
        # Obtener datos históricos
        data_row = yf.Ticker(ticker).quarterly_balance_sheet
        # Convertir el DataFrame a formato largo para facilitar la concatenación
        # data_row = data_row.reset_index()
        # Agregar el ticker como una columna en los datos históricos
        data_row['ticker'] = ticker
        # Añadir los datos a la lista
        data.append(data_row)
        print(f"Datos obtenidos para {ticker}.")
    except Exception as e:
        print(f"Error al obtener datos para {ticker}: {e}")

# Concatenar todos los DataFrames en uno solo
df = pd.concat(data, ignore_index=True)
df
# Out:
# Datos obtenidos para PCAR.
# Datos obtenidos para EQIX.
# Datos obtenidos para CNC.
# Datos obtenidos para ARE.
# Datos obtenidos para EBAY.
# Datos obtenidos para ACGL.
# Datos obtenidos para YUM.
# Datos obtenidos para BR.
# Datos obtenidos para MRK.
# Datos obtenidos para NOW.
# Datos obtenidos para ULTA.
# Datos obtenidos para BKR.
# Datos obtenidos para STE.
# Datos obtenidos para PTC.
# Datos obtenidos para UHS.
# Datos obtenidos para NVDA.
# Datos obtenidos para FANG.
# Datos obtenidos para MRO.
# Datos obtenidos para NEE.
# Datos obtenidos para DGX.
# Datos obtenidos para NSC.
# Datos obtenidos para CCL.
# Datos obtenidos para TRV.
# Datos obtenidos para F.
# Datos obtenidos para BKNG.
# Datos obtenidos para PKG.
# Datos obtenidos para MKTX.
# Datos obtenidos para UAL.
# Datos obtenidos para UPS.
# Datos obtenidos para FITB.
# Datos obtenidos para IP.
# Datos obtenidos para FFIV.
# Datos obtenidos para IFF.
# Datos obtenidos para ADP.
# Datos obtenidos para ACN.
# Datos obtenidos para MCO.
# Datos obtenidos para PARA.
# Datos obtenidos para SND.
# Datos obtenidos para MGTX.
# Datos obtenidos para QRTEB.
# Datos obtenidos para MSEX.
# Datos obtenidos para UFPI.
# Datos obtenidos para BIG.
# Datos obtenidos para APVO.
# Datos obtenidos para TRUP.
# Datos obtenidos para FBK.
# Datos obtenidos para DAX.
# Datos obtenidos para NBIX.
# Datos obtenidos para HNDL.
# Datos obtenidos para SKOR.
# Datos obtenidos para GLPI.
# Datos obtenidos para RFEU.
# Datos obtenidos para USTB.
# Datos obtenidos para AMZN.
# Datos obtenidos para IPAR.
# Datos obtenidos para TNC.
# Datos obtenidos para WISA.
# Datos obtenidos para CATC.
# Datos obtenidos para NXTC.
# Datos obtenidos para MOD.
# Datos obtenidos para MYE.
# Datos obtenidos para RUSHA.
# Datos obtenidos para BFH.
# Datos obtenidos para DDIV.
# Datos obtenidos para SIX.
# Datos obtenidos para REG.
# Datos obtenidos para FAB.
# Datos obtenidos para FTHI.
# Datos obtenidos para ARCT.
# Datos obtenidos para SNSR.
# Datos obtenidos para NXDT.
# Datos obtenidos para DWSN.
# Datos obtenidos para XELB.
# Datos obtenidos para SY.
# Datos obtenidos para AKTS.
# Datos obtenidos para AAOI.
# Datos obtenidos para CREX.
# Datos obtenidos para RSLS.
# Datos obtenidos para RFIL.
# Datos obtenidos para JYNT.
# Datos obtenidos para VTSI.
# Datos obtenidos para CDXS.
# Datos obtenidos para OXSQ.
# Datos obtenidos para PFC.
# Datos obtenidos para WAFD.
# Datos obtenidos para FMB.
# Datos obtenidos para BNDX.
# Datos obtenidos para EGBN.
# Datos obtenidos para KTB.
# Datos obtenidos para BIS.
# Datos obtenidos para ATNM.
# Datos obtenidos para LCII.
# Datos obtenidos para SSD.
# Datos obtenidos para BLKB.
# Datos obtenidos para FPXE.
# Datos obtenidos para MMM.
# Datos obtenidos para MAA.
# Datos obtenidos para CDW.
# Datos obtenidos para GNRC.
# Datos obtenidos para CAG.
# Datos obtenidos para PFG.
# Datos obtenidos para KLAC.
# Datos obtenidos para ANIX.
# Datos obtenidos para STKS.
# Datos obtenidos para REAL.
# Datos obtenidos para RIOT.
# Datos obtenidos para RNGR.
# Datos obtenidos para BYU.
# Datos obtenidos para CRIS.
# Datos obtenidos para OMI.
# Datos obtenidos para CLMT.
# Datos obtenidos para MRKR.
# Datos obtenidos para PEB.
# Datos obtenidos para VNOM.
# Datos obtenidos para AMTB.
# Datos obtenidos para FNLC.
# Datos obtenidos para CRS.
# Datos obtenidos para WB.
# Datos obtenidos para HNI.
# Datos obtenidos para QTRX.
# Datos obtenidos para OGS.
# Datos obtenidos para LPCN.
# Datos obtenidos para SXT.
# Datos obtenidos para CPK.
# Datos obtenidos para NHC.
# Datos obtenidos para SWX.
# Datos obtenidos para VMBS.
# Datos obtenidos para ONEQ.
# Datos obtenidos para CDLX.
# Datos obtenidos para MGNI.
# Datos obtenidos para SAMG.
# Datos obtenidos para CSTL.
# Datos obtenidos para LAUR.
# Datos obtenidos para SSRM.
# Datos obtenidos para HUM.
# Datos obtenidos para IRM.
# Datos obtenidos para WFC.
# Datos obtenidos para KIM.
# Datos obtenidos para V.
# Datos obtenidos para FAST.
# Datos obtenidos para CME.
# Datos obtenidos para AVY.
# Datos obtenidos para HII.
# Datos obtenidos para DXYN.
# Datos obtenidos para SPCB.
# Datos obtenidos para MCHX.
# Datos obtenidos para TOMZ.
# Datos obtenidos para AWRE.
# Datos obtenidos para LEU.
# Datos obtenidos para KMDA.
# Datos obtenidos para PXLW.
# Datos obtenidos para NCMI.
# Datos obtenidos para TACT.
# Datos obtenidos para XBIT.
# Datos obtenidos para GALT.
# Datos obtenidos para COSM.
# Datos obtenidos para AXDX.
# Datos obtenidos para DM.
# Datos obtenidos para PAVM.
# Datos obtenidos para STAF.
# Datos obtenidos para SONN.
# Datos obtenidos para DCOM.
# Datos obtenidos para INBK.
# Datos obtenidos para SNY.
# Datos obtenidos para KIDS.
# Datos obtenidos para MANH.
# Datos obtenidos para CCEP.
# Datos obtenidos para ESGD.
# Datos obtenidos para QQQ.
# Datos obtenidos para PALT.
# Datos obtenidos para WKEY.
# Datos obtenidos para NEON.
# Datos obtenidos para MFIN.
# Datos obtenidos para PXS.
# Datos obtenidos para LINC.
# Datos obtenidos para ITI.
# Datos obtenidos para WAT.
# Datos obtenidos para CVX.
# Datos obtenidos para EXPD.
# Datos obtenidos para NI.
# Datos obtenidos para HST.
# Datos obtenidos para DAL.
# Datos obtenidos para LIN.
# Datos obtenidos para CMLS.
# Datos obtenidos para JELD.
# Datos obtenidos para SATS.
# Datos obtenidos para DHC.
# Datos obtenidos para MODG.
# Datos obtenidos para ESGRO.
# Datos obtenidos para PHR.
# Datos obtenidos para LSXMB.
# Datos obtenidos para YMAB.
# Datos obtenidos para SNEX.
# Datos obtenidos para KRYS.
# Datos obtenidos para SMTI.
# Datos obtenidos para BHR.
# Datos obtenidos para SLNH.
# Datos obtenidos para CRK.
# Datos obtenidos para PLSE.
# Datos obtenidos para CNTY.
# Datos obtenidos para BEEM.
# Datos obtenidos para KOD.
# Datos obtenidos para GHC.
# Datos obtenidos para CHEK.
# Datos obtenidos para JJSF.
# Datos obtenidos para CXW.
# Datos obtenidos para TH.
# Datos obtenidos para CDZI.
# Datos obtenidos para CPSS.
# Datos obtenidos para TPCS.
# Datos obtenidos para ASC.
# Datos obtenidos para CIO.
# Datos obtenidos para EVC.
# Datos obtenidos para LWAY.
# Datos obtenidos para PESI.
# Datos obtenidos para IVAC.
# Datos obtenidos para KPTI.
# Datos obtenidos para BGC.
# Datos obtenidos para PSEC.
# Datos obtenidos para K.
# Datos obtenidos para LULU.
# Datos obtenidos para URI.
# Datos obtenidos para D.
# Datos obtenidos para UBER.
# Datos obtenidos para IR.
# Datos obtenidos para LVS.
# Datos obtenidos para LW.
# Datos obtenidos para MDT.
# Datos obtenidos para HES.
# Datos obtenidos para UNH.
# Datos obtenidos para RLMD.
# Datos obtenidos para CZWI.
# Datos obtenidos para EXTR.
# Datos obtenidos para NVFY.
# Datos obtenidos para RBBN.
# Datos obtenidos para ADPT.
# Datos obtenidos para THTX.
# Datos obtenidos para EBTC.
# Datos obtenidos para SXI.
# Datos obtenidos para LFUS.
# Datos obtenidos para FCAL.
# Datos obtenidos para ZIONP.
# Datos obtenidos para LFCR.
# Datos obtenidos para ABIO.
# Datos obtenidos para PLAB.
# Datos obtenidos para FUSB.
# Datos obtenidos para MERC.
# Datos obtenidos para NECB.
# Datos obtenidos para AUPH.
# Datos obtenidos para MDXG.
# Datos obtenidos para VYGR.
# Datos obtenidos para HFFG.
# Datos obtenidos para XHR.
# Datos obtenidos para RVSB.
# Datos obtenidos para ALLT.
# Datos obtenidos para ACRS.
# Datos obtenidos para CTOS.
# Datos obtenidos para NEO.
# Datos obtenidos para MDRR.
# Datos obtenidos para VOD.
# Datos obtenidos para SLS.
# Datos obtenidos para NVNO.
# Datos obtenidos para BXC.
# Datos obtenidos para BYFC.
# Datos obtenidos para BGFV.
# Datos obtenidos para QRTEA.
# Datos obtenidos para MIGI.
# Datos obtenidos para FGEN.
# Datos obtenidos para USAU.
# Datos obtenidos para ICCC.
# Datos obtenidos para ALTO.
# Datos obtenidos para ETN.
# Datos obtenidos para ABBV.
# Datos obtenidos para ED.
# Datos obtenidos para SMCI.
# Datos obtenidos para KO.
# Datos obtenidos para BELFB.
# Datos obtenidos para IMVT.
# Datos obtenidos para CFBK.
# Datos obtenidos para PRFZ.
# Datos obtenidos para BTAI.
# Datos obtenidos para RMBS.
# Datos obtenidos para WNC.
# Datos obtenidos para THR.
# Datos obtenidos para AGIO.
# Datos obtenidos para DCO.
# Datos obtenidos para JSMD.
# Datos obtenidos para CFA.
# Datos obtenidos para NOVT.
# Datos obtenidos para NTES.
# Datos obtenidos para RFDI.
# Datos obtenidos para ROCK.
# Datos obtenidos para AROW.
# Datos obtenidos para TLSA.
# Datos obtenidos para APLT.
# Datos obtenidos para SMHI.
# Datos obtenidos para GIGM.
# Datos obtenidos para LSAK.
# Datos obtenidos para CPIX.
# Datos obtenidos para LTRX.
# Datos obtenidos para EGIO.
# Datos obtenidos para NATR.
# Datos obtenidos para SWKH.
# Datos obtenidos para PBFS.
# Datos obtenidos para ALTS.
# Datos obtenidos para GRNQ.
# Datos obtenidos para AGBA.
# Datos obtenidos para PLYA.
# Datos obtenidos para VGR.
# Datos obtenidos para MRNS.
# Datos obtenidos para SHYF.
# Datos obtenidos para EOLS.
# Datos obtenidos para SBUX.
# Datos obtenidos para HBAN.
# Datos obtenidos para ETR.
# Datos obtenidos para GPC.
# Datos obtenidos para ZBRA.
# Datos obtenidos para IBM.
# Datos obtenidos para ES.
# Datos obtenidos para TSLA.
# Datos obtenidos para AAPL.
# Datos obtenidos para ROST.
# Datos obtenidos para DECK.
# Datos obtenidos para AMRX.
# Datos obtenidos para RRGB.
# Datos obtenidos para ACTG.
# Datos obtenidos para NICK.
# Datos obtenidos para GIFI.
# Datos obtenidos para KRNY.
# Datos obtenidos para SNCR.
# Datos obtenidos para YEXT.
# Datos obtenidos para TTGT.
# Datos obtenidos para BLNK.
# Datos obtenidos para STOK.
# Datos obtenidos para ESGRP.
# Datos obtenidos para LZB.
# Datos obtenidos para IPWR.
# Datos obtenidos para BPOP.
# Datos obtenidos para HMST.
# Datos obtenidos para WORX.
# Datos obtenidos para ANIP.
# Datos obtenidos para QLYS.
# Datos obtenidos para FIVN.
# Datos obtenidos para AIN.
# Datos obtenidos para CMRX.
# Datos obtenidos para VERU.
# Datos obtenidos para EDUC.
# Datos obtenidos para UBCP.
# Datos obtenidos para NFE.
# Datos obtenidos para RGP.
# Datos obtenidos para ACCO.
# Datos obtenidos para HEPA.
# Datos obtenidos para MPWR.
# Datos obtenidos para ODFL.
# Datos obtenidos para PWR.
# Datos obtenidos para EVRG.
# Datos obtenidos para WM.
# Datos obtenidos para RF.
# Datos obtenidos para JPM.
# Datos obtenidos para OXY.
# Datos obtenidos para ISRG.
# Datos obtenidos para RDCM.
# Datos obtenidos para ICLN.
# Datos obtenidos para VRNA.
# Datos obtenidos para TBPH.
# Datos obtenidos para CRWS.
# Datos obtenidos para OPRX.
# Datos obtenidos para SPNS.
# Datos obtenidos para LWLG.
# Datos obtenidos para FFNW.
# Datos obtenidos para CYH.
# Datos obtenidos para VECO.
# Datos obtenidos para ONVO.
# Datos obtenidos para BGRN.
# Datos obtenidos para NUS.
# Datos obtenidos para PFBC.
# Datos obtenidos para APLS.
# Datos obtenidos para IDCC.
# Datos obtenidos para CVCO.
# Datos obtenidos para BOKF.
# Datos obtenidos para GNPX.
# Datos obtenidos para ENTG.
# Datos obtenidos para PRPO.
# Datos obtenidos para VIRX.
# Datos obtenidos para CLWT.
# Datos obtenidos para MRIN.
# Datos obtenidos para CRESY.
# Datos obtenidos para DAKT.
# Datos obtenidos para FUBO.
# Datos obtenidos para SVRA.
# Datos obtenidos para CAAS.
# Datos obtenidos para SHO.
# Datos obtenidos para DXR.
# Datos obtenidos para NFBK.
# Datos obtenidos para FORD.
# Datos obtenidos para BZH.
# Datos obtenidos para AGYS.
# Datos obtenidos para CPHC.
# Datos obtenidos para UE.
# Datos obtenidos para MRBK.
# Datos obtenidos para CPS.
# Datos obtenidos para RES.
# Datos obtenidos para WHLRD.
# Datos obtenidos para GLAD.
# Datos obtenidos para COLL.
# Datos obtenidos para VCTR.
# Datos obtenidos para DENN.
# Datos obtenidos para BLMN.
# Datos obtenidos para EPAC.
# Datos obtenidos para ZLAB.
# Datos obtenidos para BSVN.
# Datos obtenidos para JSM.
# Datos obtenidos para IUS.
# Datos obtenidos para CATH.
# Datos obtenidos para PFIS.
# Datos obtenidos para APPN.
# Datos obtenidos para NXTG.
# Datos obtenidos para RGEN.
# Datos obtenidos para BLBD.
# Datos obtenidos para MEDS.
# Datos obtenidos para BSCR.
# Datos obtenidos para OI.
# Datos obtenidos para DXLG.
# Datos obtenidos para RYI.
# Datos obtenidos para PPBT.
# Datos obtenidos para KIRK.
# Datos obtenidos para GOEV.
# Datos obtenidos para FULT.
# Datos obtenidos para HFWA.
# Datos obtenidos para INBKZ.
# Datos obtenidos para FCPT.
# Datos obtenidos para HTBI.
# Datos obtenidos para PRFT.
# Datos obtenidos para MAYS.
# Datos obtenidos para BJK.
# Datos obtenidos para PAGP.
# Datos obtenidos para MODN.
# Datos obtenidos para CNOB.
# Datos obtenidos para FTXH.
# Datos obtenidos para FRPH.
# Datos obtenidos para AZN.
# Datos obtenidos para DDD.
# Datos obtenidos para OBK.
# Datos obtenidos para PRGS.
# Datos obtenidos para TFIN.
# Datos obtenidos para PAR.
# Datos obtenidos para RMR.
# Datos obtenidos para ZG.
# Datos obtenidos para ICLK.
# Datos obtenidos para MASI.
# Datos obtenidos para SYPR.
# Datos obtenidos para TIO.
# Datos obtenidos para MDJH.
# Datos obtenidos para USIO.
# Datos obtenidos para NWLI.
# Datos obtenidos para NVEC.
# Datos obtenidos para DTIL.
# Datos obtenidos para FAMI.
# Datos obtenidos para VONE.
# Datos obtenidos para MSTR.
# Datos obtenidos para ALTR.
# Datos obtenidos para FUL.
# Datos obtenidos para ITRI.
# Datos obtenidos para USPH.
# Datos obtenidos para AIV.
# Datos obtenidos para PVBC.
# Datos obtenidos para OKTA.
# Datos obtenidos para SRI.
# Datos obtenidos para SEVN.
# Datos obtenidos para SANM.
# Datos obtenidos para CCNE.
# Datos obtenidos para BBW.
# Datos obtenidos para FCEL.
# Datos obtenidos para CYTH.
# Datos obtenidos para SMBK.
# Datos obtenidos para CARS.
# Datos obtenidos para BYSI.
# Datos obtenidos para AIHS.
# Datos obtenidos para CARE.
# Datos obtenidos para VIRT.
# Datos obtenidos para AIR.
# Datos obtenidos para AEHL.
# Datos obtenidos para OSPN.
# Datos obtenidos para FCAP.
# Datos obtenidos para SCNI.
# Datos obtenidos para CHSCO.
# Datos obtenidos para INSG.
# Datos obtenidos para FISI.
# Datos obtenidos para UVE.
# Datos obtenidos para CCBG.
# Datos obtenidos para MFA.
# Datos obtenidos para FTLF.
# Datos obtenidos para TMDX.
# Datos obtenidos para PSNL.
# Datos obtenidos para GNTY.
# Datos obtenidos para SHEN.
# Datos obtenidos para SGRY.
# Datos obtenidos para NRIM.
# Datos obtenidos para UCTT.
# Datos obtenidos para SPSC.
# Datos obtenidos para KBWR.
# Datos obtenidos para DBX.
# Datos obtenidos para CIM.
# Datos obtenidos para RZLT.
# Datos obtenidos para QABA.
# Datos obtenidos para RGR.
# Datos obtenidos para PATK.
# Datos obtenidos para GRVY.
# Datos obtenidos para LGMK.
# Datos obtenidos para NURO.
# Datos obtenidos para EAST.
# Datos obtenidos para HLIO.
# Datos obtenidos para INTZ.
# Datos obtenidos para NVEE.
# Datos obtenidos para OLB.
# Datos obtenidos para SLVO.
# Datos obtenidos para ALGT.
# Datos obtenidos para AMSWA.
# Datos obtenidos para HSTM.
# Datos obtenidos para FINX.
# Datos obtenidos para ALRM.
# Datos obtenidos para SGRP.
# Datos obtenidos para FCUV.
# Datos obtenidos para PCSA.
# Datos obtenidos para NTRP.
# Datos obtenidos para KPRX.
# Datos obtenidos para MTC.
# Datos obtenidos para OVID.
# Datos obtenidos para MARA.
# Datos obtenidos para MVIS.
# Datos obtenidos para BMRA.
# Datos obtenidos para MVST.
# Datos obtenidos para AHG.
# Datos obtenidos para UONEK.
# Datos obtenidos para UTHR.
# Datos obtenidos para TRTX.
# Datos obtenidos para PPBI.
# Datos obtenidos para AVT.
# Datos obtenidos para FBIOP.
# Datos obtenidos para ATGE.
# Datos obtenidos para CTBI.
# Datos obtenidos para PALI.
# Datos obtenidos para QLGN.
# Datos obtenidos para ROG.
# Datos obtenidos para SNES.
# Datos obtenidos para ADIL.
# Datos obtenidos para JAGX.
# Datos obtenidos para BGS.
# Datos obtenidos para BMI.
# Datos obtenidos para INSW.
# Datos obtenidos para IEP.
# Datos obtenidos para FPXI.
# Datos obtenidos para HAE.
# Datos obtenidos para TRMD.
# Datos obtenidos para EAF.
# Datos obtenidos para UBFO.
# Datos obtenidos para MTLS.
# Datos obtenidos para KE.
# Datos obtenidos para MIST.
# Datos obtenidos para AADI.
# Datos obtenidos para SPTN.
# Datos obtenidos para SFM.
# Datos obtenidos para QYLD.
# Datos obtenidos para BSCS.
# Datos obtenidos para IQ.
# Datos obtenidos para TVTX.
# Datos obtenidos para LGHL.
# Datos obtenidos para CHKP.
# Datos obtenidos para WINT.
# Datos obtenidos para IMUX.
# Datos obtenidos para POAI.
# Datos obtenidos para TRVN.
# Datos obtenidos para LFWD.
# Datos obtenidos para MKSI.
# Datos obtenidos para FORTY.
# Datos obtenidos para IUSB.
# Datos obtenidos para GDOT.
# Datos obtenidos para CDC.
# Datos obtenidos para RRBI.
# Datos obtenidos para ALNY.
# Datos obtenidos para SFBS.
# Datos obtenidos para FCNCA.
# Datos obtenidos para MBCN.
# Datos obtenidos para OLLI.
# Datos obtenidos para SLRC.
# Datos obtenidos para RVLV.
# Datos obtenidos para DLX.
# Datos obtenidos para DY.
# Datos obtenidos para RRR.
# Datos obtenidos para AIRR.
# Datos obtenidos para PEZ.
# Datos obtenidos para HCAT.
# Datos obtenidos para RFEM.
# Datos obtenidos para ZM.
# Datos obtenidos para URBN.
# Datos obtenidos para WTBA.
# Datos obtenidos para VLYPO.
# Datos obtenidos para GNL.
# Datos obtenidos para FEP.
# Datos obtenidos para BSRR.
# Datos obtenidos para EPC.
# Datos obtenidos para UVSP.
# Datos obtenidos para FRAF.
# Datos obtenidos para NWFL.
# Datos obtenidos para SFBC.
# Datos obtenidos para ATEX.
# Datos obtenidos para ZKIN.
# Datos obtenidos para JVA.
# Datos obtenidos para RDFN.
# Datos obtenidos para RWT.
# Datos obtenidos para MCBC.
# Datos obtenidos para BRAG.
# Datos obtenidos para EU.
# Datos obtenidos para LPSN.
# Datos obtenidos para GNFT.
# Datos obtenidos para LOOP.
# Datos obtenidos para TTMI.
# Datos obtenidos para LPRO.
# Datos obtenidos para HOUS.
# Datos obtenidos para FUND.
# Datos obtenidos para GTEC.
# Datos obtenidos para CCOI.
# Datos obtenidos para NVRO.
# Datos obtenidos para ABVC.
# Datos obtenidos para WSFS.
# Datos obtenidos para DRQ.
# Datos obtenidos para PDP.
# Datos obtenidos para BKH.
# Datos obtenidos para QQEW.
# Datos obtenidos para UVV.
# Datos obtenidos para NCPL.
# Datos obtenidos para VATE.
# Datos obtenidos para MYRG.
# Datos obtenidos para CASH.
# Datos obtenidos para SPFI.
# Datos obtenidos para ATRC.
# Datos obtenidos para AGNCN.
# Datos obtenidos para INDY.
# Datos obtenidos para ZUMZ.
# Datos obtenidos para SHAK.
# Datos obtenidos para FTSM.
# Datos obtenidos para SPRO.
# Datos obtenidos para BOOT.
# Datos obtenidos para DHCNI.
# Datos obtenidos para UITB.
# Datos obtenidos para PSET.
# Datos obtenidos para CHI.
# Datos obtenidos para GOSS.
# Datos obtenidos para EP.
# Datos obtenidos para JBSS.
# Datos obtenidos para FLN.
# Datos obtenidos para PARR.
# Datos obtenidos para ICHR.
# Datos obtenidos para NZAC.
# Datos obtenidos para TRIP.
# Datos obtenidos para MCRI.
# Datos obtenidos para PIO.
# Datos obtenidos para HCC.
# Datos obtenidos para AXNX.
# Datos obtenidos para KALU.
# Datos obtenidos para DIOD.
# Datos obtenidos para CNDT.
# Datos obtenidos para QUAD.
# Datos obtenidos para UNFI.
# Datos obtenidos para VANI.
# Datos obtenidos para CYRX.
# Datos obtenidos para CUBA.
# Datos obtenidos para BRY.
# Datos obtenidos para KVHI.
# Datos obtenidos para NTRA.
# Datos obtenidos para AMCX.
# Datos obtenidos para RHP.
# Datos obtenidos para IBRX.
# Datos obtenidos para WOR.
# Datos obtenidos para LOGI.
# Datos obtenidos para CELH.
# Datos obtenidos para AIQ.
# Datos obtenidos para CWT.
# Datos obtenidos para GBDC.
# Datos obtenidos para ROBT.
# Datos obtenidos para FTC.
# Datos obtenidos para PKW.
# Datos obtenidos para SUSL.
# Datos obtenidos para CBT.
# Datos obtenidos para POWL.
# Datos obtenidos para CTVA.
# Datos obtenidos para PSA.
# Datos obtenidos para TMO.
# Datos obtenidos para HD.
# Datos obtenidos para TROW.
# Datos obtenidos para CNP.
# Datos obtenidos para MTD.
# Datos obtenidos para EL.
# Datos obtenidos para HON.
# Datos obtenidos para ADI.
# Datos obtenidos para SWK.
# Datos obtenidos para SRE.
# Datos obtenidos para NTRS.
# Datos obtenidos para BXP.
# Datos obtenidos para EMN.
# Datos obtenidos para TDY.
# Datos obtenidos para PYPL.
# Datos obtenidos para ANET.
# Datos obtenidos para CBOE.
# Datos obtenidos para TPR.
# Datos obtenidos para MTCH.
# Datos obtenidos para IEX.
# Datos obtenidos para ENPH.
# Datos obtenidos para EPAM.
# Datos obtenidos para AEE.
# Datos obtenidos para REGN.
# Datos obtenidos para ALGN.
# Datos obtenidos para STX.
# Datos obtenidos para TFC.
# Datos obtenidos para DRI.
# Datos obtenidos para ETSY.
# Datos obtenidos para CF.
# Datos obtenidos para TAP.
# Datos obtenidos para CPB.
# Datos obtenidos para PRU.
# Datos obtenidos para LMT.
# Datos obtenidos para NWSA.
# Datos obtenidos para BLDR.
# Datos obtenidos para FIS.
# Datos obtenidos para SPGI.
# Datos obtenidos para RJF.
# Datos obtenidos para AIZ.
# Datos obtenidos para RL.
# Datos obtenidos para LEN.
# Datos obtenidos para FCX.
# Datos obtenidos para AFL.
# Datos obtenidos para JBL.
# Datos obtenidos para IT.
# Datos obtenidos para TSN.
# Datos obtenidos para PSCC.
# Datos obtenidos para LANC.
# Datos obtenidos para ASUR.
# Datos obtenidos para MD.
# Datos obtenidos para GES.
# Datos obtenidos para AGMH.
# Datos obtenidos para FGM.
# Datos obtenidos para CATY.
# Datos obtenidos para MRVL.
# Datos obtenidos para ABG.
# Datos obtenidos para AIA.
# Datos obtenidos para GDYN.
# Datos obtenidos para TALO.
# Datos obtenidos para COLB.
# Datos obtenidos para MCHI.
# Datos obtenidos para AVNT.
# Datos obtenidos para TGNA.
# Datos obtenidos para AMLI.
# Datos obtenidos para NEPH.
# Datos obtenidos para BWB.
# Datos obtenidos para MBB.
# Datos obtenidos para VGIT.
# Datos obtenidos para QDEL.
# Datos obtenidos para SAVE.
# Datos obtenidos para FARO.
# Datos obtenidos para EQRR.
# Datos obtenidos para AMBA.
# Datos obtenidos para VCLT.
# Datos obtenidos para SAIC.
# Datos obtenidos para IRTC.
# Datos obtenidos para MDB.
# Datos obtenidos para SSB.
# Datos obtenidos para CENX.
# Datos obtenidos para ENVA.
# Datos obtenidos para ENR.
# Datos obtenidos para GSM.
# Datos obtenidos para STRL.
# Datos obtenidos para FLNG.
# Datos obtenidos para JBGS.
# Datos obtenidos para IBKR.
# Datos obtenidos para GPRE.
# Datos obtenidos para FTQI.
# Datos obtenidos para QNCX.
# Datos obtenidos para ARTW.
# Datos obtenidos para CLIR.
# Datos obtenidos para LXRX.
# Datos obtenidos para TTI.
# Datos obtenidos para IPDN.
# Datos obtenidos para BOSC.
# Datos obtenidos para OCUP.
# Datos obtenidos para MCS.
# Datos obtenidos para TUR.
# Datos obtenidos para AZZ.
# Datos obtenidos para STRA.
# Datos obtenidos para GCTK.
# Datos obtenidos para IXUS.
# Datos obtenidos para EQBK.
# Datos obtenidos para ISHP.
# Datos obtenidos para PGC.
# Datos obtenidos para KMI.
# Datos obtenidos para GE.
# Datos obtenidos para CB.
# Datos obtenidos para ADM.
# Datos obtenidos para VMC.
# Datos obtenidos para DIS.
# Datos obtenidos para REFR.
# Datos obtenidos para WHLM.
# Datos obtenidos para SLNG.
# Datos obtenidos para EPIX.
# Datos obtenidos para PERI.
# Datos obtenidos para RVYL.
# Datos obtenidos para ALDX.
# Datos obtenidos para FLGT.
# Datos obtenidos para NEXT.
# Datos obtenidos para MNTX.
# Datos obtenidos para ACMR.
# Datos obtenidos para SRTS.
# Datos obtenidos para SIRI.
# Datos obtenidos para ELA.
# Datos obtenidos para AGNCM.
# Datos obtenidos para LBTYA.
# Datos obtenidos para HMN.
# Datos obtenidos para PSN.
# Datos obtenidos para VSDA.
# Datos obtenidos para LKFN.
# Datos obtenidos para ACWI.
# Datos obtenidos para FYT.
# Datos obtenidos para CSR.
# Datos obtenidos para MORN.
# Datos obtenidos para CSPI.
# Datos obtenidos para SWI.
# Datos obtenidos para SLCA.
# Datos obtenidos para AGNC.
# Datos obtenidos para GCBC.
# Datos obtenidos para USAP.
# Datos obtenidos para UEIC.
# Datos obtenidos para ARLP.
# Datos obtenidos para INN.
# Datos obtenidos para LADR.
# Datos obtenidos para DMLP.
# Datos obtenidos para XYL.
# Datos obtenidos para GLW.
# Datos obtenidos para ROP.
# Datos obtenidos para STZ.
# Datos obtenidos para MSI.
# Datos obtenidos para KR.
# Datos obtenidos para HAL.
# Datos obtenidos para FICO.
# Datos obtenidos para PCG.
# Datos obtenidos para CINF.
# Datos obtenidos para OPTN.
# Datos obtenidos para AAME.
# Datos obtenidos para ATOS.
# Datos obtenidos para TXMD.
# Datos obtenidos para GENE.
# Datos obtenidos para DVAX.
# Datos obtenidos para CGEN.
# Datos obtenidos para NDLS.
# Datos obtenidos para CRVL.
# Datos obtenidos para CETX.
# Datos obtenidos para AVGR.
# Datos obtenidos para NTB.
# Datos obtenidos para ITGR.
# Datos obtenidos para NWL.
# Datos obtenidos para CHCO.
# Datos obtenidos para KBWB.
# Datos obtenidos para LSCC.
# Datos obtenidos para AGM.
# Datos obtenidos para OPK.
# Datos obtenidos para GASS.
# Datos obtenidos para ATEC.
# Datos obtenidos para CRNT.
# Datos obtenidos para CTAS.
# Datos obtenidos para LNT.
# Datos obtenidos para A.
# Datos obtenidos para CRL.
# Datos obtenidos para AMCR.
# Datos obtenidos para UNP.
# Datos obtenidos para NXPI.
# Datos obtenidos para MCK.
# Datos obtenidos para LRCX.
# Datos obtenidos para VTRS.
# Datos obtenidos para BK.
# Datos obtenidos para BIIB.
# Datos obtenidos para APLE.
# Datos obtenidos para RPD.
# Datos obtenidos para KREF.
# Datos obtenidos para VONG.
# Datos obtenidos para FTXN.
# Datos obtenidos para TNET.
# Datos obtenidos para EMB.
# Datos obtenidos para SIGA.
# Datos obtenidos para TELL.
# Datos obtenidos para CTLP.
# Datos obtenidos para SELF.
# Datos obtenidos para CVGI.
# Datos obtenidos para ZVRA.
# Datos obtenidos para SB.
# Datos obtenidos para CELC.
# Datos obtenidos para SLDB.
# Datos obtenidos para AIOT.
# Datos obtenidos para AIFF.
# Datos obtenidos para FNGR.
# Datos obtenidos para SEIC.
# Datos obtenidos para PHIO.
# Datos obtenidos para UNF.
# Datos obtenidos para PY.
# Datos obtenidos para NITO.
# Datos obtenidos para NPK.
# Datos obtenidos para RTH.
# Datos obtenidos para VIGI.
# Datos obtenidos para FDUS.
# Datos obtenidos para LXP.
# Datos obtenidos para HBIO.
# Datos obtenidos para VEV.
# Datos obtenidos para ELSE.
# Datos obtenidos para DHT.
# Datos obtenidos para OPCH.
# Datos obtenidos para GILT.
# Datos obtenidos para OGI.
# Datos obtenidos para OMC.
# Datos obtenidos para TEL.
# Datos obtenidos para EIX.
# Datos obtenidos para AON.
# Datos obtenidos para EOG.
# Datos obtenidos para JBLU.
# Datos obtenidos para PDEX.
# Datos obtenidos para SPOK.
# Datos obtenidos para BCOV.
# Datos obtenidos para VCEL.
# Datos obtenidos para TATT.
# Datos obtenidos para AXL.
# Datos obtenidos para CNFR.
# Datos obtenidos para KRO.
# Datos obtenidos para AWH.
# Datos obtenidos para YTRA.
# Datos obtenidos para CRDF.
# Datos obtenidos para AVTX.
# Datos obtenidos para FEUZ.
# Datos obtenidos para LEGR.
# Datos obtenidos para UFPT.
# Datos obtenidos para SMBC.
# Datos obtenidos para GRID.
# Datos obtenidos para VWOB.
# Datos obtenidos para MFLX.
# Datos obtenidos para MIRM.
# Datos obtenidos para CTRE.
# Datos obtenidos para ARCC.
# Datos obtenidos para DLTH.
# Datos obtenidos para LSBK.
# Datos obtenidos para PBYI.
# Datos obtenidos para AEYE.
# Datos obtenidos para AMRC.
# Datos obtenidos para HRZN.
# Datos obtenidos para TGTX.
# Datos obtenidos para AVD.
# Datos obtenidos para SOI.
# Datos obtenidos para PBPB.
# Datos obtenidos para PMD.
# Datos obtenidos para STKL.
# Datos obtenidos para DGICA.
# Datos obtenidos para ECVT.
# Datos obtenidos para KOPN.
# Datos obtenidos para GEO.
# Datos obtenidos para KZIA.
# Datos obtenidos para CLAR.
# Datos obtenidos para TBBK.
# Datos obtenidos para LAB.
# Datos obtenidos para IMXI.
# Datos obtenidos para NTIC.
# Datos obtenidos para AKBA.
# Datos obtenidos para HDSN.
# Datos obtenidos para CLPR.
# Datos obtenidos para METC.
# Datos obtenidos para VIVK.
# Datos obtenidos para CL.
# Datos obtenidos para PAYX.
# Datos obtenidos para FOX.
# Datos obtenidos para AMD.
# Datos obtenidos para APD.
# Datos obtenidos para JKHY.
# Datos obtenidos para MGM.
# Datos obtenidos para LBAI.
# Datos obtenidos para KW.
# Datos obtenidos para SCS.
# Datos obtenidos para ARTL.
# Datos obtenidos para ALRS.
# Datos obtenidos para BANX.
# Datos obtenidos para FDBC.
# Datos obtenidos para GMGI.
# Datos obtenidos para FATE.
# Datos obtenidos para IBTX.
# Datos obtenidos para PAHC.
# Datos obtenidos para TRS.
# Datos obtenidos para ALCO.
# Datos obtenidos para QTWO.
# Datos obtenidos para CRSP.
# Datos obtenidos para ESPO.
# Datos obtenidos para COKE.
# Datos obtenidos para CHDN.
# Datos obtenidos para PTF.
# Datos obtenidos para OSG.
# Datos obtenidos para CORT.
# Datos obtenidos para EVI.
# Datos obtenidos para ILPT.
# Datos obtenidos para NVAX.
# Datos obtenidos para PACB.
# Datos obtenidos para MICS.
# Datos obtenidos para XAIR.
# Datos obtenidos para CCO.
# Datos obtenidos para CBZ.
# Datos obtenidos para PETZ.
# Datos obtenidos para OSBC.
# Datos obtenidos para VEON.
# Datos obtenidos para CREG.
# Datos obtenidos para ABUS.
# Datos obtenidos para CAMT.
# Datos obtenidos para VST.
# Datos obtenidos para DE.
# Datos obtenidos para TTWO.
# Datos obtenidos para EXC.
# Datos obtenidos para MSFT.
# Datos obtenidos para GIS.
# Datos obtenidos para GL.
# Datos obtenidos para FOXA.
# Datos obtenidos para SVA.
# Datos obtenidos para HTHT.
# Datos obtenidos para DNOW.
# Datos obtenidos para GAIN.
# Datos obtenidos para CHGG.
# Datos obtenidos para EVO.
# Datos obtenidos para ACGLO.
# Datos obtenidos para GMS.
# Datos obtenidos para CMTL.
# Datos obtenidos para FAAR.
# Datos obtenidos para CKPT.
# Datos obtenidos para SKIL.
# Datos obtenidos para DEA.
# Datos obtenidos para XRX.
# Datos obtenidos para BSJO.
# Datos obtenidos para PWOD.
# Datos obtenidos para PSCD.
# Datos obtenidos para HYLS.
# Datos obtenidos para FNX.
# Datos obtenidos para CSF.
# Datos obtenidos para RGLD.
# Datos obtenidos para MCVT.
# Datos obtenidos para LQDA.
# Datos obtenidos para WFCF.
# Datos obtenidos para ENG.
# Datos obtenidos para ESSA.
# Datos obtenidos para FCCO.
# Datos obtenidos para EGAN.
# Datos obtenidos para FORM.
# Datos obtenidos para NKE.
# Datos obtenidos para AEP.
# Datos obtenidos para DLR.
# Datos obtenidos para LH.
# Datos obtenidos para HRL.
# Datos obtenidos para ESS.
# Datos obtenidos para ZTS.
# Datos obtenidos para COST.
# Datos obtenidos para TDG.
# Datos obtenidos para ACHV.
# Datos obtenidos para IRIX.
# Datos obtenidos para BOTJ.
# Datos obtenidos para RICK.
# Datos obtenidos para AFBI.
# Datos obtenidos para TZOO.
# Datos obtenidos para LOCO.
# Datos obtenidos para HHS.
# Datos obtenidos para MDRX.
# Datos obtenidos para POR.
# Datos obtenidos para PLOW.
# Datos obtenidos para OPI.
# Datos obtenidos para AADR.
# Datos obtenidos para GKOS.
# Datos obtenidos para UTMD.
# Datos obtenidos para TAOP.
# Datos obtenidos para VTVT.
# Datos obtenidos para CJJD.
# Datos obtenidos para LRMR.
# Datos obtenidos para CVV.
# Datos obtenidos para SFIX.
# Datos obtenidos para ARWR.
# Datos obtenidos para GTX.
# Datos obtenidos para VMD.
# Datos obtenidos para DNTH.
# Datos obtenidos para FF.
# Datos obtenidos para PR.
# Datos obtenidos para SPNT.
# Datos obtenidos para TRVG.
# Datos obtenidos para FVCB.
# Datos obtenidos para ALBT.
# Datos obtenidos para RUN.
# Datos obtenidos para KELYB.
# Datos obtenidos para CHEF.
# Datos obtenidos para SOHOB.
# Datos obtenidos para ASIX.
# Datos obtenidos para SIBN.
# Datos obtenidos para LCUT.
# Datos obtenidos para CODI.
# Datos obtenidos para BPYPO.
# Datos obtenidos para CHUY.
# Datos obtenidos para GTY.
# Datos obtenidos para BRID.
# Datos obtenidos para QTEC.
# Datos obtenidos para PTGX.
# Datos obtenidos para NSP.
# Datos obtenidos para PRO.
# Datos obtenidos para ORA.
# Datos obtenidos para PIPR.
# Datos obtenidos para DDS.
# Datos obtenidos para MATX.
# Datos obtenidos para APTO.
# Datos obtenidos para WVE.
# Datos obtenidos para POLA.
# Datos obtenidos para ULBI.
# Datos obtenidos para VOXX.
# Datos obtenidos para OPRA.
# Datos obtenidos para MWA.
# Datos obtenidos para MITK.
# Datos obtenidos para FULC.
# Datos obtenidos para BHAT.
# Datos obtenidos para SBH.
# Datos obtenidos para KRNT.
# Datos obtenidos para GECCM.
# Datos obtenidos para FBIZ.
# Datos obtenidos para QTTB.
# Datos obtenidos para CHMG.
# Datos obtenidos para ARCB.
# Datos obtenidos para VTOL.
# Datos obtenidos para MEI.
# Datos obtenidos para ORC.
# Datos obtenidos para CHSCN.
# Datos obtenidos para LRN.
# Datos obtenidos para FOXF.
# Datos obtenidos para PBH.
# Datos obtenidos para GMAB.
# Datos obtenidos para DFIN.
# Datos obtenidos para GLPG.
# Datos obtenidos para FN.
# Datos obtenidos para DOYU.
# Datos obtenidos para XYLO.
# Datos obtenidos para ASTE.
# Datos obtenidos para FV.
# Datos obtenidos para TRNO.
# Datos obtenidos para GOLF.
# Datos obtenidos para ASMB.
# Datos obtenidos para HYMC.
# Datos obtenidos para BH.
# Datos obtenidos para TANH.
# Datos obtenidos para OBLG.
# Datos obtenidos para BBGI.
# Datos obtenidos para SYRS.
# Datos obtenidos para FRGT.
# Datos obtenidos para HY.
# Datos obtenidos para FIBK.
# Datos obtenidos para EAT.
# Datos obtenidos para ALE.
# Datos obtenidos para TXRH.
# Datos obtenidos para IMCV.
# Datos obtenidos para BNDW.
# Datos obtenidos para FIVE.
# Datos obtenidos para BNTC.
# Datos obtenidos para RUSHB.
# Datos obtenidos para OCSL.
# Datos obtenidos para MNSB.
# Datos obtenidos para FBZ.
# Datos obtenidos para HPKEW.
# Datos obtenidos para DNLI.
# Datos obtenidos para UXIN.
# Datos obtenidos para BCML.
# Datos obtenidos para MXL.
# Datos obtenidos para REPX.
# Datos obtenidos para CYCN.
# Datos obtenidos para SNAX.
# Datos obtenidos para COOP.
# Datos obtenidos para LARK.
# Datos obtenidos para QQQX.
# Datos obtenidos para GPMT.
# Datos obtenidos para MVBF.
# Datos obtenidos para BATRK.
# Datos obtenidos para WTFCM.
# Datos obtenidos para EBF.
# Datos obtenidos para FTXO.
# Datos obtenidos para JAKK.
# Datos obtenidos para CBFV.
# Datos obtenidos para DOGZ.
# Datos obtenidos para NBN.
# Datos obtenidos para STNG.
# Datos obtenidos para SUPN.
# Datos obtenidos para CGNX.
# Datos obtenidos para SFNC.
# Datos obtenidos para RDHL.
# Datos obtenidos para SURG.
# Datos obtenidos para CHRS.
# Datos obtenidos para SFST.
# Datos obtenidos para BANFP.
# Datos obtenidos para CADE.
# Datos obtenidos para OCX.
# Datos obtenidos para GO.
# Datos obtenidos para YORW.
# Datos obtenidos para SBOW.
# Datos obtenidos para PTMN.
# Datos obtenidos para SMSI.
# Datos obtenidos para SCSC.
# Datos obtenidos para CLDX.
# Datos obtenidos para XCUR.
# Datos obtenidos para FLR.
# Datos obtenidos para PNM.
# Datos obtenidos para IGF.
# Datos obtenidos para TIGO.
# Datos obtenidos para DGLY.
# Datos obtenidos para ARTNA.
# Datos obtenidos para CYCC.
# Datos obtenidos para EWBC.
# Datos obtenidos para QXO.
# Datos obtenidos para IMTE.
# Datos obtenidos para PRK.
# Datos obtenidos para CEAD.
# Datos obtenidos para AYRO.
# Datos obtenidos para EMIF.
# Datos obtenidos para TMHC.
# Datos obtenidos para LOB.
# Datos obtenidos para AIRT.
# Datos obtenidos para CIVI.
# Datos obtenidos para SDVY.
# Datos obtenidos para RGNX.
# Datos obtenidos para BANF.
# Datos obtenidos para BKYI.
# Datos obtenidos para NRBO.
# Datos obtenidos para VKTX.
# Datos obtenidos para KFY.
# Datos obtenidos para SSTK.
# Datos obtenidos para AGX.
# Datos obtenidos para PMT.
# Datos obtenidos para BYON.
# Datos obtenidos para MNKD.
# Datos obtenidos para DVOL.
# Datos obtenidos para FALN.
# Datos obtenidos para TRN.
# Datos obtenidos para ESGE.
# Datos obtenidos para STBA.
# Datos obtenidos para XRAY.
# Datos obtenidos para IIPR.
# Datos obtenidos para ASTC.
# Datos obtenidos para ABCB.
# Datos obtenidos para PFX.
# Datos obtenidos para ABM.
# Datos obtenidos para CSWI.
# Datos obtenidos para LITE.
# Datos obtenidos para CMCT.
# Datos obtenidos para HURN.
# Datos obtenidos para IEF.
# Datos obtenidos para INFN.
# Datos obtenidos para EZPW.
# Datos obtenidos para AHH.
# Datos obtenidos para CGBD.
# Datos obtenidos para MRTN.
# Datos obtenidos para PDFS.
# Datos obtenidos para OLP.
# Datos obtenidos para CBAN.
# Datos obtenidos para NTGR.
# Datos obtenidos para SLM.
# Datos obtenidos para PFS.
# Datos obtenidos para OXSQZ.
# Datos obtenidos para JRVR.
# Datos obtenidos para AZPN.
# Datos obtenidos para AAXJ.
# Datos obtenidos para PNRG.
# Datos obtenidos para RNAC.
# Datos obtenidos para NPO.
# Datos obtenidos para ITIC.
# Datos obtenidos para CGC.
# Datos obtenidos para SQQQ.
# Datos obtenidos para CTS.
# Datos obtenidos para CALM.
# Datos obtenidos para EEFT.
# Datos obtenidos para ROIC.
# Datos obtenidos para FTDS.
# Datos obtenidos para MEDP.
# Datos obtenidos para VCIT.
# Datos obtenidos para ALG.
# Datos obtenidos para KLXE.
# Datos obtenidos para TCTM.
# Datos obtenidos para QCLN.
# Datos obtenidos para RLJ.
# Datos obtenidos para TDIV.
# Datos obtenidos para XTKG.
# Datos obtenidos para IMOM.
# Datos obtenidos para EXPI.
# Datos obtenidos para AKR.
# Datos obtenidos para HYXF.
# Datos obtenidos para HLNE.
# Datos obtenidos para FFIN.
# Datos obtenidos para SEDG.
# Datos obtenidos para BSJP.
# Datos obtenidos para CHSCM.
# Datos obtenidos para FITBI.
# Datos obtenidos para ZIONO.
# Datos obtenidos para KRMA.
# Datos obtenidos para HAIN.
# Datos obtenidos para VSTO.
# Datos obtenidos para QUIK.
# Datos obtenidos para INGN.
# Datos obtenidos para CFFN.
# Datos obtenidos para STIM.
# Datos obtenidos para ATIF.
# Datos obtenidos para SYBX.
# Datos obtenidos para ADAP.
# Datos obtenidos para EGRX.
# Datos obtenidos para NAII.
# Datos obtenidos para CFB.
# Datos obtenidos para FRHC.
# Datos obtenidos para GDC.
# Datos obtenidos para PTH.
# Datos obtenidos para UNB.
# Datos obtenidos para AVNS.
# Datos obtenidos para LIVN.
# Datos obtenidos para SONM.
# Datos obtenidos para TSE.
# Datos obtenidos para AEIS.
# Datos obtenidos para GATX.
# Datos obtenidos para BRKL.
# Datos obtenidos para SBRA.
# Datos obtenidos para PID.
# Datos obtenidos para AY.
# Datos obtenidos para BPRN.
# Datos obtenidos para SMPL.
# Datos obtenidos para CAL.
# Datos obtenidos para ULVM.
# Datos obtenidos para CARG.
# Datos obtenidos para KALV.
# Datos obtenidos para CHX.
# Datos obtenidos para FEMB.
# Datos obtenidos para XT.
# Datos obtenidos para FTCS.
# Datos obtenidos para BDC.
# Datos obtenidos para ERIC.
# Datos obtenidos para IRWD.
# Datos obtenidos para BE.
# Datos obtenidos para HWBK.
# Datos obtenidos para FSS.
# Datos obtenidos para WINC.
# Datos obtenidos para KLIC.
# Datos obtenidos para PPC.
# Datos obtenidos para REZI.
# Datos obtenidos para CSV.
# Datos obtenidos para ENZL.
# Datos obtenidos para CAR.
# Datos obtenidos para MIDD.
# Datos obtenidos para BLCN.
# Datos obtenidos para EYE.
# Datos obtenidos para PNQI.
# Datos obtenidos para DWSH.
# Datos obtenidos para INVA.
# Datos obtenidos para KN.
# Datos obtenidos para AEHR.
# Datos obtenidos para FLXS.
# Datos obtenidos para CENTA.
# Datos obtenidos para GSAT.
# Datos obtenidos para ASGN.
# Datos obtenidos para SUSC.
# Datos obtenidos para LBRDK.
# Datos obtenidos para MBIN.
# Datos obtenidos para BOTZ.
# Datos obtenidos para TOWN.
# Datos obtenidos para TQQQ.
# Datos obtenidos para TRMB.
# Datos obtenidos para GDDY.
# Datos obtenidos para DAY.
# Datos obtenidos para CHRW.
# Datos obtenidos para WRB.
# Datos obtenidos para WMT.
# Datos obtenidos para TECH.
# Datos obtenidos para CDNS.
# Datos obtenidos para CHD.
# Datos obtenidos para WST.
# Datos obtenidos para ELV.
# Datos obtenidos para MRNA.
# Datos obtenidos para PHM.
# Datos obtenidos para JNJ.
# Datos obtenidos para EMR.
# Datos obtenidos para DHI.
# Datos obtenidos para JBHT.
# Datos obtenidos para CTRA.
# Datos obtenidos para DUK.
# Datos obtenidos para ABT.
# Datos obtenidos para SYK.
# Datos obtenidos para HSIC.
# Datos obtenidos para TFX.
# Datos obtenidos para QRVO.
# Datos obtenidos para HPQ.
# Datos obtenidos para LYB.
# Datos obtenidos para LYV.
# Datos obtenidos para BWA.
# Datos obtenidos para INTU.
# Datos obtenidos para BBY.
# Datos obtenidos para JCI.
# Datos obtenidos para MS.
# Datos obtenidos para C.
# Datos obtenidos para TPC.
# Datos obtenidos para SAGE.
# Datos obtenidos para EMXC.
# Datos obtenidos para RCON.
# Datos obtenidos para WAFU.
# Datos obtenidos para BZUN.
# Datos obtenidos para MGIC.
# Datos obtenidos para STEL.
# Datos obtenidos para ANGL.
# Datos obtenidos para APCX.
# Datos obtenidos para PKBK.
# Datos obtenidos para SQLV.
# Datos obtenidos para DWAS.
# Datos obtenidos para SIGI.
# Datos obtenidos para CIL.
# Datos obtenidos para VXUS.
# Datos obtenidos para FWONK.
# Datos obtenidos para PRKS.
# Datos obtenidos para VSMV.
# Datos obtenidos para BATRA.
# Datos obtenidos para ENS.
# Datos obtenidos para TCMD.
# Datos obtenidos para KBWP.
# Datos obtenidos para SYNA.
# Datos obtenidos para NWN.
# Datos obtenidos para KEQU.
# Datos obtenidos para PRIM.
# Datos obtenidos para KELYA.
# Datos obtenidos para KTOS.
# Datos obtenidos para SRDX.
# Datos obtenidos para BHE.
# Datos obtenidos para ESQ.
# Datos obtenidos para CMBM.
# Datos obtenidos para GNOM.
# Datos obtenidos para AFYA.
# Datos obtenidos para LRGE.
# Datos obtenidos para FSEA.
# Datos obtenidos para VFF.
# Datos obtenidos para GECC.
# Datos obtenidos para WTTR.
# Datos obtenidos para FTDR.
# Datos obtenidos para TRMK.
# Datos obtenidos para COMT.
# Datos obtenidos para BRFH.
# Datos obtenidos para YJ.
# Datos obtenidos para ERNA.
# Datos obtenidos para IMMP.
# Datos obtenidos para HIHO.
# Datos obtenidos para DHX.
# Datos obtenidos para SPI.
# Datos obtenidos para FLL.
# Datos obtenidos para QUBT.
# Datos obtenidos para RGCO.
# Datos obtenidos para DTSS.
# Datos obtenidos para OII.
# Datos obtenidos para UIVM.
# Datos obtenidos para ACHC.
# Datos obtenidos para BFC.
# Datos obtenidos para USNA.
# Datos obtenidos para BANR.
# Datos obtenidos para SHY.
# Datos obtenidos para VC.
# Datos obtenidos para VERO.
# Datos obtenidos para ATNF.
# Datos obtenidos para XTIA.
# Datos obtenidos para PETQ.
# Datos obtenidos para PRAA.
# Datos obtenidos para MGYR.
# Datos obtenidos para UTZ.
# Datos obtenidos para IDYA.
# Datos obtenidos para DOW.
# Datos obtenidos para PEP.
# Datos obtenidos para CFG.
# Datos obtenidos para HPE.
# Datos obtenidos para AES.
# Datos obtenidos para MA.
# Datos obtenidos para WBD.
# Datos obtenidos para BRO.
# Datos obtenidos para MU.
# Datos obtenidos para DAIO.
# Datos obtenidos para CMCL.
# Datos obtenidos para CPRX.
# Datos obtenidos para SMID.
# Datos obtenidos para SSSS.
# Datos obtenidos para ASRV.
# Datos obtenidos para BXMT.
# Datos obtenidos para GIC.
# Datos obtenidos para TSEM.
# Datos obtenidos para ASTH.
# Datos obtenidos para BPMC.
# Datos obtenidos para IBP.
# Datos obtenidos para BMRN.
# Datos obtenidos para SAFT.
# Datos obtenidos para TPIC.
# Datos obtenidos para SRET.
# Datos obtenidos para CASY.
# Datos obtenidos para WOOD.
# Datos obtenidos para ORMP.
# Datos obtenidos para PT.
# Datos obtenidos para PTSI.
# Datos obtenidos para NNBR.
# Datos obtenidos para AMBC.
# Datos obtenidos para CMS.
# Datos obtenidos para USB.
# Datos obtenidos para SNA.
# Datos obtenidos para FTNT.
# Datos obtenidos para ANSS.
# Datos obtenidos para CPRT.
# Datos obtenidos para MPC.
# Datos obtenidos para GS.
# Datos obtenidos para NTWK.
# Datos obtenidos para RELL.
# Datos obtenidos para LIQT.
# Datos obtenidos para DUOT.
# Datos obtenidos para KGEI.
# Datos obtenidos para ABEO.
# Datos obtenidos para INDV.
# Datos obtenidos para VIRC.
# Datos obtenidos para COGT.
# Datos obtenidos para CNET.
# Datos obtenidos para TNFA.
# Datos obtenidos para XELA.
# Datos obtenidos para IBB.
# Datos obtenidos para VISL.
# Datos obtenidos para SEEL.
# Datos obtenidos para SCOR.
# Datos obtenidos para WHD.
# Datos obtenidos para ODP.
# Datos obtenidos para PBF.
# Datos obtenidos para NGVT.
# Datos obtenidos para CLW.
# Datos obtenidos para MODV.
# Datos obtenidos para GROW.
# Datos obtenidos para MNDO.
# Datos obtenidos para OMEX.
# Datos obtenidos para SWKS.
# Datos obtenidos para MNST.
# Datos obtenidos para PSX.
# Datos obtenidos para IQV.
# Datos obtenidos para VZ.
# Datos obtenidos para CMCSA.
# Datos obtenidos para PH.
# Datos obtenidos para JNPR.
# Datos obtenidos para MRC.
# Datos obtenidos para TILE.
# Datos obtenidos para HRTX.
# Datos obtenidos para NOG.
# Datos obtenidos para BKE.
# Datos obtenidos para MDWD.
# Datos obtenidos para SABR.
# Datos obtenidos para VLYPP.
# Datos obtenidos para EVA.
# Datos obtenidos para PFF.
# Datos obtenidos para WLFC.
# Datos obtenidos para RYAAY.
# Datos obtenidos para BTBT.
# Datos obtenidos para GURE.
# Datos obtenidos para TLF.
# Datos obtenidos para HPH.
# Datos obtenidos para LINK.
# Datos obtenidos para KALA.
# Datos obtenidos para EGY.
# Datos obtenidos para BHRB.
# Datos obtenidos para JAZZ.
# Datos obtenidos para DHIL.
# Datos obtenidos para MTW.
# Datos obtenidos para PPIH.
# Datos obtenidos para PGRE.
# Datos obtenidos para PANL.
# Datos obtenidos para MNMD.
# Datos obtenidos para QNTM.
# Datos obtenidos para ORGS.
# Datos obtenidos para GPRO.
# Datos obtenidos para DRS.
# Datos obtenidos para NAT.
# Datos obtenidos para BLDP.
# Datos obtenidos para EEX.
# Datos obtenidos para CNSL.
# Datos obtenidos para CDMO.
# Datos obtenidos para ENLV.
# Datos obtenidos para BTU.
# Datos obtenidos para PNC.
# Datos obtenidos para DOC.
# Datos obtenidos para AXP.
# Datos obtenidos para SYY.
# Datos obtenidos para CAH.
# Datos obtenidos para ADBE.
# Datos obtenidos para RMD.
# Datos obtenidos para BAX.
# Datos obtenidos para VTR.
# Datos obtenidos para CI.
# Datos obtenidos para RCEL.
# Datos obtenidos para RENB.
# Datos obtenidos para WVVI.
# Datos obtenidos para ACIU.
# Datos obtenidos para FRPT.
# Datos obtenidos para GSIT.
# Datos obtenidos para ADVM.
# Datos obtenidos para ATER.
# Datos obtenidos para EWZS.
# Datos obtenidos para NIU.
# Datos obtenidos para BCRX.
# Datos obtenidos para RDVT.
# Datos obtenidos para FVC.
# Datos obtenidos para GRC.
# Datos obtenidos para OZK.
# Datos obtenidos para BBH.
# Datos obtenidos para CRUS.
# Datos obtenidos para DX.
# Datos obtenidos para LEGH.
# Datos obtenidos para PKE.
# Datos obtenidos para DRH.
# Datos obtenidos para BVFL.
# Datos obtenidos para ACEL.
# Datos obtenidos para NMFC.
# Datos obtenidos para FNKO.
# Datos obtenidos para CGO.
# Datos obtenidos para HONE.
# Datos obtenidos para SFL.
# Datos obtenidos para VICR.
# Datos obtenidos para BV.
# Datos obtenidos para ZYME.
# Datos obtenidos para KTCC.
# Datos obtenidos para HPK.
# Datos obtenidos para ANGO.
# Datos obtenidos para GT.
# Datos obtenidos para NWBI.
# Datos obtenidos para LTBR.
# Datos obtenidos para WSBF.
# Datos obtenidos para NEGG.
# Datos obtenidos para UG.
# Datos obtenidos para ARL.
# Datos obtenidos para WULF.
# Datos obtenidos para AMPY.
# Datos obtenidos para RGLS.
# Datos obtenidos para CRMD.
# Datos obtenidos para TWIN.
# Datos obtenidos para LEDS.
# Datos obtenidos para TECTP.
# Datos obtenidos para WNEB.
# Datos obtenidos para SLP.
# Datos obtenidos para CCI.
# Datos obtenidos para BALL.
# Datos obtenidos para CAT.
# Datos obtenidos para TXT.
# Datos obtenidos para ALB.
# Datos obtenidos para MHK.
# Datos obtenidos para MAS.
# Datos obtenidos para FE.
# Datos obtenidos para ROL.
# Datos obtenidos para AME.
# Datos obtenidos para INVH.
# Datos obtenidos para GPN.
# Datos obtenidos para RDI.
# Datos obtenidos para PSHG.
# Datos obtenidos para HUT.
# Datos obtenidos para DLHC.
# Datos obtenidos para CMC.
# Datos obtenidos para CLMB.
# Datos obtenidos para WSC.
# Datos obtenidos para AVDL.
# Datos obtenidos para SOHU.
# Datos obtenidos para CTO.
# Datos obtenidos para ALKS.
# Datos obtenidos para BWFG.
# Datos obtenidos para HZO.
# Datos obtenidos para SOXX.
# Datos obtenidos para UTL.
# Datos obtenidos para DIN.
# Datos obtenidos para TECX.
# Datos obtenidos para OXM.
# Datos obtenidos para CLB.
# Datos obtenidos para IDN.
# Datos obtenidos para SNT.
# Datos obtenidos para TRUE.
# Datos obtenidos para ISSC.
# Datos obtenidos para ATLC.
# Datos obtenidos para REI.
# Datos obtenidos para AVXL.
# Datos obtenidos para BWEN.
# Datos obtenidos para PRTH.
# Datos obtenidos para SBT.
# Datos obtenidos para ICAD.
# Datos obtenidos para COMM.
# Datos obtenidos para GREE.
# Datos obtenidos para GYRO.
# Datos obtenidos para BBSI.
# Datos obtenidos para TTSH.
# Datos obtenidos para HOOK.
# Datos obtenidos para HEAR.
# Datos obtenidos para KA.
# Datos obtenidos para SHIP.
# Datos obtenidos para BLX.
# Datos obtenidos para REVG.
# Datos obtenidos para GOOGL.
# Datos obtenidos para RCL.
# Datos obtenidos para BLK.
# Datos obtenidos para DD.
# Datos obtenidos para NOC.
# Datos obtenidos para DOV.
# Datos obtenidos para AVGO.
# Datos obtenidos para LDOS.
# Datos obtenidos para ADSK.
# Datos obtenidos para MCHP.
# Datos obtenidos para MCD.
# Datos obtenidos para ITW.
# Datos obtenidos para PGR.
# Datos obtenidos para IVZ.
# Datos obtenidos para NMTC.
# Datos obtenidos para ATYR.
# Datos obtenidos para GLDD.
# Datos obtenidos para MBI.
# Datos obtenidos para ADMA.
# Datos obtenidos para JILL.
# Datos obtenidos para CALX.
# Datos obtenidos para TURN.
# Datos obtenidos para DZSI.
# Datos obtenidos para KFS.
# Datos obtenidos para BOXL.
# Datos obtenidos para MGY.
# Datos obtenidos para SIXG.
# Datos obtenidos para ISTR.
# Datos obtenidos para EVTC.
# Datos obtenidos para AUBN.
# Datos obtenidos para PIZ.
# Datos obtenidos para WASH.
# Datos obtenidos para CSGS.
# Datos obtenidos para HURC.
# Datos obtenidos para FMBH.
# Datos obtenidos para RCKT.
# Datos obtenidos para CNX.
# Datos obtenidos para BAND.
# Datos obtenidos para RM.
# Datos obtenidos para WSBC.
# Datos obtenidos para UCBI.
# Datos obtenidos para CVLT.
# Datos obtenidos para MTX.
# Datos obtenidos para LPLA.
# Datos obtenidos para HMNF.
# Datos obtenidos para FPI.
# Datos obtenidos para FOLD.
# Datos obtenidos para STRR.
# Datos obtenidos para LEE.
# Datos obtenidos para ESCA.
# Datos obtenidos para CHNR.
# Datos obtenidos para OCCI.
# Datos obtenidos para CRVS.
# Datos obtenidos para PRSO.
# Datos obtenidos para BDN.
# Datos obtenidos para EVH.
# Datos obtenidos para APH.
# Datos obtenidos para CE.
# Datos obtenidos para CMI.
# Datos obtenidos para CVS.
# Datos obtenidos para BRK-B.
# Datos obtenidos para MMC.
# Datos obtenidos para LKQ.
# Datos obtenidos para KFFB.
# Datos obtenidos para SGML.
# Datos obtenidos para ARKO.
# Datos obtenidos para EBMT.
# Datos obtenidos para NCSM.
# Datos obtenidos para FOR.
# Datos obtenidos para USLM.
# Datos obtenidos para VSH.
# Datos obtenidos para PLUG.
# Datos obtenidos para NKSH.
# Datos obtenidos para SBET.
# Datos obtenidos para NICE.
# Datos obtenidos para USIG.
# Datos obtenidos para GRPN.
# Datos obtenidos para SHV.
# Datos obtenidos para NKLA.
# Datos obtenidos para ENSC.
# Datos obtenidos para EMCB.
# Datos obtenidos para SCWO.
# Datos obtenidos para UEC.
# Datos obtenidos para UTSI.
# Datos obtenidos para BW.
# Datos obtenidos para CARV.
# Datos obtenidos para TIGR.
# Datos obtenidos para RCM.
# Datos obtenidos para GOGL.
# Datos obtenidos para DYAI.
# Datos obtenidos para OFG.
# Datos obtenidos para WLDN.
# Datos obtenidos para RC.
# Datos obtenidos para FLNT.
# Datos obtenidos para DXJS.
# Datos obtenidos para UTI.
# Datos obtenidos para UPLD.
# Datos obtenidos para WW.
# Datos obtenidos para TCPC.
# Datos obtenidos para CNO.
# Datos obtenidos para MDIV.
# Datos obtenidos para TDS.
# Datos obtenidos para QURE.
# Datos obtenidos para NEWT.
# Datos obtenidos para BSET.
# Datos obtenidos para PNBK.
# Datos obtenidos para XBIO.
# Datos obtenidos para ANIK.
# Datos obtenidos para GVA.
# Datos obtenidos para BKU.
# ...
# Datos obtenidos para SBAC.
# Datos obtenidos para MG.
# Datos obtenidos para TROX.
# Datos obtenidos para CDE.
# Datos obtenidos para NL.
# Datos obtenidos para NERV.
# Datos obtenidos para EVTV.
# Datos obtenidos para LGO.
# Datos obtenidos para CLPT.
# Datos obtenidos para BWAY.
# Datos obtenidos para KNSA.
# Datos obtenidos para MPX.
# Datos obtenidos para KMT.
# Datos obtenidos para SGA.
# Datos obtenidos para UBSI.
# Datos obtenidos para VLGEA.
# Datos obtenidos para BCO.
# Datos obtenidos para EBS.
# Datos obtenidos para OTEX.
# Datos obtenidos para VABK.
# Datos obtenidos para LIVE.
# Datos obtenidos para RMAX.
# Datos obtenidos para CZFS.
# Datos obtenidos para VNET.
# Datos obtenidos para WEN.
# Datos obtenidos para MLKN.
# Datos obtenidos para MMI.
# Datos obtenidos para AMSF.
# Datos obtenidos para BL.
# Datos obtenidos para AQST.
# Datos obtenidos para QRHC.
# Datos obtenidos para CLNE.
# Datos obtenidos para BCTX.
# Datos obtenidos para VS.
# Datos obtenidos para TARA.
# Datos obtenidos para CWCO.
# Datos obtenidos para MYFW.
# Datos obtenidos para CVLY.
# Datos obtenidos para ATHE.
# Datos obtenidos para EQ.
# Datos obtenidos para FID.
# Datos obtenidos para CARM.
# Datos obtenidos para MOS.
# Datos obtenidos para KEY.
# Datos obtenidos para POOL.
# Datos obtenidos para CSX.
# Datos obtenidos para NDAQ.
# Datos obtenidos para LOW.
# Datos obtenidos para KEYS.
# Datos obtenidos para LHX.
# Datos obtenidos para HNRG.
# Datos obtenidos para JRSH.
# Datos obtenidos para JCTCF.
# Datos obtenidos para BCOW.
# Datos obtenidos para APYX.
# Datos obtenidos para FAT.
# Datos obtenidos para GTN.
# Datos obtenidos para LE.
# Datos obtenidos para HRI.
# Datos obtenidos para FCFS.
# Datos obtenidos para BNGO.
# Datos obtenidos para PDD.
# Datos obtenidos para FBIO.
# Datos obtenidos para AIT.
# Datos obtenidos para MTEM.
# Datos obtenidos para TC.
# Datos obtenidos para PIRS.
# Datos obtenidos para MELI.
# Datos obtenidos para XWEL.
# Datos obtenidos para PETS.
# Datos obtenidos para TG.
# Datos obtenidos para PTEN.
# Datos obtenidos para LFVN.
# Datos obtenidos para GNW.
# Datos obtenidos para FTFT.
# Datos obtenidos para FSLY.
# Datos obtenidos para BBCP.
# Datos obtenidos para PDSB.
# Datos obtenidos para NOTV.
# Datos obtenidos para LPTH.
# Datos obtenidos para ANGI.
# Datos obtenidos para WHLRP.
# Datos obtenidos para CWK.
# Datos obtenidos para BCAL.
# Datos obtenidos para RIGL.
# Datos obtenidos para SSKN.
# Datos obtenidos para RBB.
# Datos obtenidos para DGICB.
# Datos obtenidos para LKCO.
# Datos obtenidos para PRDO.
# Datos obtenidos para JMSB.
# Datos obtenidos para MORF.
# Datos obtenidos para PULM.
# Datos obtenidos para IPI.
# Datos obtenidos para WSR.
# Datos obtenidos para APM.
# Datos obtenidos para MEC.
# Datos obtenidos para QAT.
# Datos obtenidos para BILI.
# Datos obtenidos para FSTR.
# Datos obtenidos para ALEC.
# Datos obtenidos para BLRX.
# Datos obtenidos para TWO.
# Datos obtenidos para EGHT.
# Datos obtenidos para RGS.
# Datos obtenidos para XXII.
# Datos obtenidos para MLAB.
# Datos obtenidos para PLUS.
# Datos obtenidos para ICFI.
# Datos obtenidos para SNGX.
# Datos obtenidos para FENC.
# Datos obtenidos para SBFG.
# Datos obtenidos para BKD.
# Datos obtenidos para WVVIP.
# Datos obtenidos para CLGN.
# Datos obtenidos para SOHO.
# Datos obtenidos para SNOA.
# Datos obtenidos para GLNG.
# Datos obtenidos para GRFS.
# Datos obtenidos para VRA.
# Datos obtenidos para ACET.
# Datos obtenidos para RMCF.
# Datos obtenidos para ALTY.
# Datos obtenidos para CLFD.
# Datos obtenidos para SSP.
# Datos obtenidos para CSTE.
# Datos obtenidos para FRME.
# Datos obtenidos para FBMS.
# Datos obtenidos para GH.
# Datos obtenidos para PTNQ.
# Datos obtenidos para VHI.
# Datos obtenidos para LRFC.
# Datos obtenidos para SAH.
# Datos obtenidos para VRIG.
# Datos obtenidos para YLDE.
# Datos obtenidos para CNS.
# Datos obtenidos para PSL.
# Datos obtenidos para TEX.
# Datos obtenidos para SLQD.
# Datos obtenidos para OFIX.
# Datos obtenidos para FL.
# Datos obtenidos para MMS.
# Datos obtenidos para ZS.
# Datos obtenidos para ASND.
# Datos obtenidos para OCGN.
# Datos obtenidos para OMCL.
# Datos obtenidos para DJCO.
# Datos obtenidos para ATRI.
# Datos obtenidos para GWAV.
# Datos obtenidos para LAMR.
# Datos obtenidos para PJT.
# Datos obtenidos para ENTA.
# Datos obtenidos para JBT.
# Datos obtenidos para ASML.
# Datos obtenidos para DGRE.
# Datos obtenidos para BFS.
# Datos obtenidos para GABC.
# Datos obtenidos para TCX.
# Datos obtenidos para FWRD.
# Datos obtenidos para GTBP.
# Datos obtenidos para CIGI.
# Datos obtenidos para LBRDA.
# Datos obtenidos para KAI.
# Datos obtenidos para RCRT.
# Datos obtenidos para FTXL.
# Datos obtenidos para LILA.
# Datos obtenidos para PSCH.
# Datos obtenidos para FGBI.
# Datos obtenidos para CYBR.
# Datos obtenidos para ISHG.
# Datos obtenidos para WRLD.
# Datos obtenidos para BOOM.
# Datos obtenidos para ESRT.
# Datos obtenidos para ACAD.
# Datos obtenidos para ATOM.
# Datos obtenidos para SHBI.
# Datos obtenidos para ARQ.
# Datos obtenidos para FOSL.
# Datos obtenidos para MAT.
# Datos obtenidos para CVBF.
# Datos obtenidos para PIXY.
# Datos obtenidos para AORT.
# Datos obtenidos para NBHC.
# Datos obtenidos para FTAG.
# Datos obtenidos para BCYC.
# Datos obtenidos para IRMD.
# Datos obtenidos para FONR.
# Datos obtenidos para EFOI.
# Datos obtenidos para MRUS.
# Datos obtenidos para HSII.
# Datos obtenidos para ITRN.
# Datos obtenidos para SPWR.
# Datos obtenidos para TBI.
# Datos obtenidos para BHFAL.
# Datos obtenidos para ECOW.
# Datos obtenidos para BRTX.
# Datos obtenidos para MTDR.
# Datos obtenidos para ATLO.
# Datos obtenidos para FDP.
# Datos obtenidos para COFS.
# Datos obtenidos para CEVA.
# Datos obtenidos para OTRK.
# Datos obtenidos para CCLDP.
# Datos obtenidos para SGLY.
# Datos obtenidos para TUSK.
# Datos obtenidos para STR.
# Datos obtenidos para JG.
# Datos obtenidos para ANDE.
# Datos obtenidos para HPP.
# Datos obtenidos para NBTB.
# Datos obtenidos para MEIP.
# Datos obtenidos para CWH.
# Datos obtenidos para SMLR.
# Datos obtenidos para PI.
# Datos obtenidos para MBIO.
# Datos obtenidos para OMAB.
# Datos obtenidos para CDTX.
# Datos obtenidos para NCTY.
# Datos obtenidos para TLPH.
# Datos obtenidos para NATH.
# Datos obtenidos para WINA.
# Datos obtenidos para WATT.
# Datos obtenidos para MYGN.
# Datos obtenidos para FGFPP.
# Datos obtenidos para AGEN.
# Datos obtenidos para ATRO.
# Datos obtenidos para SYBT.
# Datos obtenidos para VCNX.
# Datos obtenidos para CBRL.
# Datos obtenidos para APDN.
# Datos obtenidos para AYTU.
# Datos obtenidos para CSCI.
# Datos obtenidos para CYTO.
# Datos obtenidos para HGBL.
# Datos obtenidos para RSSS.
# Datos obtenidos para INCR.
# Datos obtenidos para MFH.
# Datos obtenidos para POCI.
# Datos obtenidos para GTIM.
# Datos obtenidos para SLE.
# Datos obtenidos para FCVT.
# Datos obtenidos para QVAL.
# Datos obtenidos para BIB.
# Datos obtenidos para IHRT.
# Datos obtenidos para CLOU.
# Datos obtenidos para SPXC.
# Datos obtenidos para OEC.
# Datos obtenidos para ODC.
# Datos obtenidos para PCTY.
# Datos obtenidos para KBWY.
# Datos obtenidos para AEMD.
# Datos obtenidos para NBR.
# Datos obtenidos para MYSZ.
# Datos obtenidos para RETO.
# Datos obtenidos para MATV.
# Datos obtenidos para SMP.
# Datos obtenidos para NNI.
# Datos obtenidos para LSXMA.
# Datos obtenidos para CFFI.
# Datos obtenidos para NSIT.
# Datos obtenidos para LDWY.
# Datos obtenidos para GMRE.
# Datos obtenidos para KBWD.
# Datos obtenidos para CTRN.
# Datos obtenidos para MINDP.
# Datos obtenidos para PAA.
# Datos obtenidos para GLT.
# Datos obtenidos para MTRN.
# Datos obtenidos para HOV.
# Datos obtenidos para FYC.
# Datos obtenidos para PSCE.
# Datos obtenidos para JOE.
# Datos obtenidos para PHUN.
# Datos obtenidos para LSTA.
# Datos obtenidos para CRVO.
# Datos obtenidos para CBUS.
# Datos obtenidos para TWOU.
# Datos obtenidos para TW.
# Datos obtenidos para EXPO.
# Datos obtenidos para IFRX.
# Datos obtenidos para SSNC.
# Datos obtenidos para VSTM.
# Datos obtenidos para WWD.
# Datos obtenidos para FEX.
# Datos obtenidos para PSCI.
# Datos obtenidos para ARGX.
# Datos obtenidos para KRG.
# Datos obtenidos para LBRT.
# Datos obtenidos para AKRO.
# Datos obtenidos para NKTR.
# Datos obtenidos para MSBI.
# Datos obtenidos para SAIA.
# Datos obtenidos para AOSL.
# Datos obtenidos para ESLT.
# Datos obtenidos para TRAW.
# Datos obtenidos para GLMD.
# Datos obtenidos para ACIC.
# Datos obtenidos para DK.
# Datos obtenidos para SPWH.
# Datos obtenidos para KZR.
# Datos obtenidos para HIVE.
# Datos obtenidos para NAVI.
# Datos obtenidos para CUTR.
# Datos obtenidos para WWW.
# Datos obtenidos para ATKR.
# Datos obtenidos para HYZD.
# Datos obtenidos para FCEF.
# Datos obtenidos para BPOPM.
# Datos obtenidos para INSM.
# Datos obtenidos para AGS.
# Datos obtenidos para FEMS.
# Datos obtenidos para BIDU.
# Datos obtenidos para LGND.
# Datos obtenidos para FYX.
# Datos obtenidos para IIIV.
# Datos obtenidos para PDCO.
# Datos obtenidos para ITCI.
# Datos obtenidos para FDNI.
# Datos obtenidos para ESGU.
# Datos obtenidos para XNCR.
# Datos obtenidos para FNY.
# Datos obtenidos para AAT.
# Datos obtenidos para ACLS.
# Datos obtenidos para CLPS.
# Datos obtenidos para MPAA.
# Datos obtenidos para LUMN.
# Datos obtenidos para TFSL.
# Datos obtenidos para OSS.
# Datos obtenidos para DBVT.
# Datos obtenidos para MTRX.
# Datos obtenidos para LQDT.
# Datos obtenidos para UIS.
# Datos obtenidos para AMKR.
# Datos obtenidos para GWRS.
# Datos obtenidos para COHU.
# Datos obtenidos para AXSM.
# Datos obtenidos para WTFC.
# Datos obtenidos para ITRM.
# Datos obtenidos para CELU.
# Datos obtenidos para CLBK.
# Datos obtenidos para SCPH.
# Datos obtenidos para SHRY.
# Datos obtenidos para MBWM.
# Datos obtenidos para MTSI.
# Datos obtenidos para ARLO.
# Datos obtenidos para MCY.
# Datos obtenidos para PYZ.
# Datos obtenidos para FNWB.
# Datos obtenidos para PIE.
# Datos obtenidos para ADTN.
# Datos obtenidos para BFST.
# Datos obtenidos para HQY.
# Datos obtenidos para WDFC.
# Datos obtenidos para FIZZ.
# Datos obtenidos para SR.
# Datos obtenidos para NMRK.
# Datos obtenidos para BUSE.
# Datos obtenidos para LASR.
# Datos obtenidos para PSCF.
# Datos obtenidos para FNK.
# Datos obtenidos para LSTR.
# Datos obtenidos para QMOM.
# Datos obtenidos para ADEA.
# Datos obtenidos para CHCT.
# Datos obtenidos para COLM.
# Datos obtenidos para SNFCA.
# Datos obtenidos para LYFT.
# Datos obtenidos para KAR.
# Datos obtenidos para BITF.
# Datos obtenidos para UEVM.
# Datos obtenidos para ZION.
# Datos obtenidos para CMMB.
# Datos obtenidos para MED.
# Datos obtenidos para KURA.
# Datos obtenidos para MATW.
# Datos obtenidos para RDVY.
# Datos obtenidos para BRKR.
# Datos obtenidos para ONCY.
# Datos obtenidos para PUMP.
# Datos obtenidos para STRS.
# Datos obtenidos para RNSC.
# Datos obtenidos para SMCP.
# Datos obtenidos para VREX.
# Datos obtenidos para BTOG.
# Datos obtenidos para LTC.
# Datos obtenidos para ZEUS.
# Datos obtenidos para ELF.
# Datos obtenidos para MMSI.
# Datos obtenidos para SGBX.
# Datos obtenidos para BLUE.
#        2024-06-30 00:00:00 2024-03-31 00:00:00 2023-12-31 00:00:00  \
# 0                  40000.0             40000.0             40000.0
# 1              524300000.0         524060000.0         523300000.0
# 2              524340000.0         524100000.0         523340000.0
# 3             8533500000.0        7835200000.0        7052800000.0
# 4            14405000000.0       14029700000.0       14234500000.0
# ...                    ...                 ...                 ...
# 199944                 NaN                 NaN                 NaN
# 199945                 NaN                 NaN                 NaN
# 199946                 NaN                 NaN                 NaN
# 199947                 NaN                 NaN                 NaN
# 199948                 NaN                 NaN                 NaN
#
#        2023-09-30 00:00:00 2023-06-30 00:00:00 2023-03-31 00:00:00  \
# 0                  40000.0             40000.0                 NaN
# 1              523060000.0         522760000.0                 NaN
# 2              523100000.0         522800000.0                 NaN
# 3             7019300000.0        7444200000.0                 NaN
# 4            12925600000.0       12590100000.0                 NaN
# ...                    ...                 ...                 ...
# 199944          23000000.0          15435000.0          15539000.0
# 199945          23000000.0          15435000.0          15539000.0
# 199946         174293000.0         245303000.0         318257000.0
# 199947           8946000.0          72431000.0          79212000.0
# 199948         165347000.0         172872000.0         239045000.0
#
#        2022-12-31 00:00:00 ticker 2024-04-30 00:00:00 2024-01-31 00:00:00  \
# 0                      NaN   PCAR                 NaN                 NaN
# 1                      NaN   PCAR                 NaN                 NaN
# 2                      NaN   PCAR                 NaN                 NaN
# 3                      NaN   PCAR                 NaN                 NaN
# 4                      NaN   PCAR                 NaN                 NaN
# ...                    ...    ...                 ...                 ...
# 199944          10787000.0   BLUE                 NaN                 NaN
# 199945          10787000.0   BLUE                 NaN                 NaN
# 199946         180327000.0   BLUE                 NaN                 NaN
# 199947          67321000.0   BLUE                 NaN                 NaN
# 199948         113006000.0   BLUE                 NaN                 NaN
#
#         ... 2023-07-31 00:00:00 2023-04-30 00:00:00 2023-01-31 00:00:00  \
# 0       ...                 NaN                 NaN                 NaN
# 1       ...                 NaN                 NaN                 NaN
# 2       ...                 NaN                 NaN                 NaN
# 3       ...                 NaN                 NaN                 NaN
# 4       ...                 NaN                 NaN                 NaN
# ...     ...                 ...                 ...                 ...
# 199944  ...                 NaN                 NaN                 NaN
# 199945  ...                 NaN                 NaN                 NaN
# 199946  ...                 NaN                 NaN                 NaN
# 199947  ...                 NaN                 NaN                 NaN
# 199948  ...                 NaN                 NaN                 NaN
#
#        2024-07-31 00:00:00 2024-05-31 00:00:00 2024-02-29 00:00:00  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 199944                 NaN                 NaN                 NaN
# 199945                 NaN                 NaN                 NaN
# 199946                 NaN                 NaN                 NaN
# 199947                 NaN                 NaN                 NaN
# 199948                 NaN                 NaN                 NaN
#
#        2023-11-30 00:00:00 2023-08-31 00:00:00 2023-05-31 00:00:00  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 199944                 NaN                 NaN                 NaN
# 199945                 NaN                 NaN                 NaN
# 199946                 NaN                 NaN                 NaN
# 199947                 NaN                 NaN                 NaN
# 199948                 NaN                 NaN                 NaN
#
#        2023-02-28 00:00:00
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 199944                 NaN
# 199945                 NaN
# 199946                 NaN
# 199947                 NaN
# 199948                 NaN
#
# [199949 rows x 21 columns]

# %%
# Asegurarse de que los nombres de las columnas sean strings y recórtalos
df.columns = [str(col)[:10] for col in df.columns]

# %%
# Identificar columnas de tipo 'object'
object_columns = df.select_dtypes(include=['object']).columns

# Convertir las columnas de tipo 'object' a listas
for col in object_columns:
    df[col] = df[col].apply(lambda x: json.dumps(x) if isinstance(x, (list, dict)) else x)

# %%
# Guardamos los datos en bigquery
bigquery.save_dataframe(df, project, dataset, table, if_exists='replace', schema=None)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
