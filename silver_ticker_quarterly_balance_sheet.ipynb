# %%
from datetime import datetime
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud import bigquery
from google.cloud.exceptions import NotFound
import pandas as pd
import numpy as np
import yahoo_fin.stock_info as si
from utils.utils_bigquery import *
from datetime import *

# %%
key_path = key_path
project = project_id

# Sources
table = 'bronze_ticker_quarterly_balance_sheet'
dataset = 'bronze'
table_conca = f'{project}.{dataset}.{table}'

# Loading tables
table_to_save = 'silver_ticker_quarterly_balance_sheet'
dataset_to_save = 'silver'
table_conca_to_save = f'{project}.{dataset_to_save}.{table_to_save}'

# %%
# Conectamos con Bigquery
bigquery = BigQueryUtils(key_path)

# %%
df = bigquery.run_query(
    f"""
    SELECT
        *
    FROM {project}.{dataset}.{table}
    """
)
df
# Out:
#        ticker                      date  Accounts Payable  \
# 0           A 2022-10-01 00:00:00+00:00       488000000.0
# 1           A 2022-10-02 00:00:00+00:00       488000000.0
# 2           A 2022-10-03 00:00:00+00:00       488000000.0
# 3           A 2022-10-04 00:00:00+00:00       488000000.0
# 4           A 2022-10-05 00:00:00+00:00       488000000.0
# ...       ...                       ...               ...
# 300813    ZTS 2023-03-27 00:00:00+00:00               NaN
# 300814    ZTS 2023-03-28 00:00:00+00:00               NaN
# 300815    ZTS 2023-03-29 00:00:00+00:00               NaN
# 300816    ZTS 2023-03-30 00:00:00+00:00               NaN
# 300817    ZTS 2023-03-31 00:00:00+00:00               NaN
#
#         Accounts Receivable  Accrued Interest Receivable  \
# 0              1.295000e+09                          NaN
# 1              1.295000e+09                          NaN
# 2              1.295000e+09                          NaN
# 3              1.295000e+09                          NaN
# 4              1.295000e+09                          NaN
# ...                     ...                          ...
# 300813                  NaN                          NaN
# 300814                  NaN                          NaN
# 300815                  NaN                          NaN
# 300816                  NaN                          NaN
# 300817                  NaN                          NaN
#
#         Accumulated Depreciation  Additional Paid In Capital  \
# 0                            NaN                5.440000e+09
# 1                            NaN                5.440000e+09
# 2                            NaN                5.440000e+09
# 3                            NaN                5.440000e+09
# 4                            NaN                5.440000e+09
# ...                          ...                         ...
# 300813                       NaN                         NaN
# 300814                       NaN                         NaN
# 300815                       NaN                         NaN
# 300816                       NaN                         NaN
# 300817                       NaN                         NaN
#
#         Allowance For Doubtful Accounts Receivable  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 300813                                         NaN
# 300814                                         NaN
# 300815                                         NaN
# 300816                                         NaN
# 300817                                         NaN
#
#         Assets Held For Sale Current  Available For Sale Securities  ...  \
# 0                                NaN                            NaN  ...
# 1                                NaN                            NaN  ...
# 2                                NaN                            NaN  ...
# 3                                NaN                            NaN  ...
# 4                                NaN                            NaN  ...
# ...                              ...                            ...  ...
# 300813                           NaN                            NaN  ...
# 300814                           NaN                            NaN  ...
# 300815                           NaN                            NaN  ...
# 300816                           NaN                            NaN  ...
# 300817                           NaN                            NaN  ...
#
#         Total Non Current Liabilities Net Minority Interest  \
# 0                                            3.143000e+09
# 1                                            3.143000e+09
# 2                                            3.143000e+09
# 3                                            3.143000e+09
# 4                                            3.143000e+09
# ...                                                   ...
# 300813                                                NaN
# 300814                                                NaN
# 300815                                                NaN
# 300816                                                NaN
# 300817                                                NaN
#
#         Total Tax Payable  Tradeand Other Payables Non Current  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
# 2                     NaN                                  NaN
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
# ...                   ...                                  ...
# 300813                NaN                                  NaN
# 300814                NaN                                  NaN
# 300815                NaN                                  NaN
# 300816                NaN                                  NaN
# 300817                NaN                                  NaN
#
#         Trading Securities  Treasury Shares Number  Treasury Stock  \
# 0                      NaN                     NaN             NaN
# 1                      NaN                     NaN             NaN
# 2                      NaN                     NaN             NaN
# 3                      NaN                     NaN             NaN
# 4                      NaN                     NaN             NaN
# ...                    ...                     ...             ...
# 300813                 NaN                     NaN             NaN
# 300814                 NaN                     NaN             NaN
# 300815                 NaN                     NaN             NaN
# 300816                 NaN                     NaN             NaN
# 300817                 NaN                     NaN             NaN
#
#         Unrealized Gain Loss  Work In Process  Working Capital  \
# 0                        NaN              NaN     2.721000e+09
# 1                        NaN              NaN     2.721000e+09
# 2                        NaN              NaN     2.721000e+09
# 3                        NaN              NaN     2.721000e+09
# 4                        NaN              NaN     2.721000e+09
# ...                      ...              ...              ...
# 300813                   NaN              NaN              NaN
# 300814                   NaN              NaN              NaN
# 300815                   NaN              NaN              NaN
# 300816                   NaN              NaN              NaN
# 300817                   NaN              NaN              NaN
#
#                                       id
# 0       83203239d0e1d42c77b64b271fafd177
# 1       d75bc63b32a9cca9f630e53f131d0631
# 2       29550cb7997e3a540d64a821d26f9633
# 3       7e748b61840f443093c15611bb99f8f2
# 4       b61b0ac40a7ae75c4e1a0ba9e546bc7a
# ...                                  ...
# 300813  25eaafae8a987c170b2d18b690091d8d
# 300814  6fb47480b1d439fbc6fda834a15cc54d
# 300815  479e00f7af2e713722c26f1d1a09c357
# 300816  bda664e3dc4007fa82709671987c3741
# 300817  e8909304f47d0df65fe2bef6db4a83f3
#
# [300818 rows x 142 columns]

# %%
apple = df[df['ticker']=='AAPL']
apple
# Out:
#        ticker                      date  Accounts Payable  \
# 913      AAPL 2022-10-01 00:00:00+00:00      5.814600e+10
# 914      AAPL 2022-10-02 00:00:00+00:00      5.814600e+10
# 915      AAPL 2022-10-03 00:00:00+00:00      5.814600e+10
# 916      AAPL 2022-10-04 00:00:00+00:00      5.814600e+10
# 917      AAPL 2022-10-05 00:00:00+00:00      5.814600e+10
# ...       ...                       ...               ...
# 229821   AAPL 2023-03-27 00:00:00+00:00               NaN
# 229822   AAPL 2023-03-28 00:00:00+00:00               NaN
# 229823   AAPL 2023-03-29 00:00:00+00:00               NaN
# 229824   AAPL 2023-03-30 00:00:00+00:00               NaN
# 229825   AAPL 2023-03-31 00:00:00+00:00               NaN
#
#         Accounts Receivable  Accrued Interest Receivable  \
# 913            2.319400e+10                          NaN
# 914            2.319400e+10                          NaN
# 915            2.319400e+10                          NaN
# 916            2.319400e+10                          NaN
# 917            2.319400e+10                          NaN
# ...                     ...                          ...
# 229821                  NaN                          NaN
# 229822                  NaN                          NaN
# 229823                  NaN                          NaN
# 229824                  NaN                          NaN
# 229825                  NaN                          NaN
#
#         Accumulated Depreciation  Additional Paid In Capital  \
# 913                -7.251000e+10                         NaN
# 914                -7.251000e+10                         NaN
# 915                -7.251000e+10                         NaN
# 916                -7.251000e+10                         NaN
# 917                -7.251000e+10                         NaN
# ...                          ...                         ...
# 229821                       NaN                         NaN
# 229822                       NaN                         NaN
# 229823                       NaN                         NaN
# 229824                       NaN                         NaN
# 229825                       NaN                         NaN
#
#         Allowance For Doubtful Accounts Receivable  \
# 913                                            NaN
# 914                                            NaN
# 915                                            NaN
# 916                                            NaN
# 917                                            NaN
# ...                                            ...
# 229821                                         NaN
# 229822                                         NaN
# 229823                                         NaN
# 229824                                         NaN
# 229825                                         NaN
#
#         Assets Held For Sale Current  Available For Sale Securities  ...  \
# 913                              NaN                   9.947500e+10  ...
# 914                              NaN                   9.947500e+10  ...
# 915                              NaN                   9.947500e+10  ...
# 916                              NaN                   9.947500e+10  ...
# 917                              NaN                   9.947500e+10  ...
# ...                              ...                            ...  ...
# 229821                           NaN                            NaN  ...
# 229822                           NaN                            NaN  ...
# 229823                           NaN                            NaN  ...
# 229824                           NaN                            NaN  ...
# 229825                           NaN                            NaN  ...
#
#         Total Non Current Liabilities Net Minority Interest  \
# 913                                          1.454410e+11
# 914                                          1.454410e+11
# 915                                          1.454410e+11
# 916                                          1.454410e+11
# 917                                          1.454410e+11
# ...                                                   ...
# 229821                                                NaN
# 229822                                                NaN
# 229823                                                NaN
# 229824                                                NaN
# 229825                                                NaN
#
#         Total Tax Payable  Tradeand Other Payables Non Current  \
# 913                   NaN                                  NaN
# 914                   NaN                                  NaN
# 915                   NaN                                  NaN
# 916                   NaN                                  NaN
# 917                   NaN                                  NaN
# ...                   ...                                  ...
# 229821                NaN                                  NaN
# 229822                NaN                                  NaN
# 229823                NaN                                  NaN
# 229824                NaN                                  NaN
# 229825                NaN                                  NaN
#
#         Trading Securities  Treasury Shares Number  Treasury Stock  \
# 913                    NaN                     0.0             NaN
# 914                    NaN                     0.0             NaN
# 915                    NaN                     0.0             NaN
# 916                    NaN                     0.0             NaN
# 917                    NaN                     0.0             NaN
# ...                    ...                     ...             ...
# 229821                 NaN                     NaN             NaN
# 229822                 NaN                     NaN             NaN
# 229823                 NaN                     NaN             NaN
# 229824                 NaN                     NaN             NaN
# 229825                 NaN                     NaN             NaN
#
#         Unrealized Gain Loss  Work In Process  Working Capital  \
# 913                      NaN              NaN     9.719000e+09
# 914                      NaN              NaN     9.719000e+09
# 915                      NaN              NaN     9.719000e+09
# 916                      NaN              NaN     9.719000e+09
# 917                      NaN              NaN     9.719000e+09
# ...                      ...              ...              ...
# 229821                   NaN              NaN              NaN
# 229822                   NaN              NaN              NaN
# 229823                   NaN              NaN              NaN
# 229824                   NaN              NaN              NaN
# 229825                   NaN              NaN              NaN
#
#                                       id
# 913     856fc6e87e98fa7d658095d5c0398677
# 914     91aa5a3388ce0788d513a03d25cef9ca
# 915     a3799b3ab3f763a23723bdc070873c7a
# 916     1e68bfec67c3ee81cb2f7fd2f2958e9a
# 917     4ab9a730570038dc6d36bc4079f8be92
# ...                                  ...
# 229821  bafd04e68fd49da7bba7016f20a6cbde
# 229822  b351d04551b45f75514f85a41380a5d8
# 229823  a6d3929b8867b01ebc8c997c79191623
# 229824  07a53624dd8a19a8e35e10a817ebde99
# 229825  53c16904a5225d4b9e305869be0821fb
#
# [639 rows x 142 columns]

# %%
# Function to calculate the percentage of empty cells for each column
def percentage_empty_cells_per_column(df):
    
    # Calculate the percentage of empty cells for each column
    empty_percentage = df.isna().mean() * 100
    return empty_percentage

# Function to remove columns where the percentage of empty cells is less than a given threshold
def remove_columns_with_low_empty_percentage(df, threshold):
    # Get the percentage of empty cells for each column using the first function
    empty_percentage = percentage_empty_cells_per_column(df)
    
    # Select columns with empty percentage greater than or equal to the threshold
    columns_to_keep = empty_percentage[empty_percentage >= threshold].index
    
    # Return DataFrame with the selected columns
    filtered_df = df[columns_to_keep]
    return filtered_df

threshold = 50  # Threshold percentage

df_vacias = percentage_empty_cells_per_column(apple)
df_vacias
# Out:
# ticker                           0.000000
# date                             0.000000
# Accounts Payable                28.482003
# Accounts Receivable             28.482003
# Accrued Interest Receivable    100.000000
#                                   ...
# Treasury Stock                 100.000000
# Unrealized Gain Loss           100.000000
# Work In Process                100.000000
# Working Capital                 28.482003
# id                               0.000000
# Length: 142, dtype: float64

# %%
def remove_columns_with_low_empty_percentage(df, threshold):
    # Calculate the percentage of empty cells for each column
    empty_percentage = df.isna().mean() * 100
    
    # Select columns with empty percentage greater than or equal to the threshold
    columns_to_keep = empty_percentage[empty_percentage >= threshold].index
    
    # Return DataFrame with the selected columns
    return df[columns_to_keep]

threshold = 50  # Threshold percentage

filtered_df = remove_columns_with_low_empty_percentage(apple, threshold)
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 639 entries, 913 to 229825
# Data columns (total 86 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Accrued Interest Receivable                                           0 non-null      float64
#  1   Additional Paid In Capital                                            0 non-null      float64
#  2   Allowance For Doubtful Accounts Receivable                            0 non-null      float64
#  3   Assets Held For Sale Current                                          0 non-null      float64
#  4   Buildings And Improvements                                            0 non-null      float64
#  5   Capital Lease Obligations                                             92 non-null     float64
#  6   Cash Cash Equivalents And Federal Funds Sold                          0 non-null      float64
#  7   Construction In Progress                                              0 non-null      float64
#  8   Current Accrued Expenses                                              0 non-null      float64
#  9   Current Capital Lease Obligation                                      92 non-null     float64
#  10  Current Deferred Assets                                               0 non-null      float64
#  11  Current Deferred Taxes Assets                                         0 non-null      float64
#  12  Current Deferred Taxes Liabilities                                    0 non-null      float64
#  13  Current Notes Payable                                                 0 non-null      float64
#  14  Current Provisions                                                    0 non-null      float64
#  15  Defined Pension Benefit                                               0 non-null      float64
#  16  Derivative Product Liabilities                                        0 non-null      float64
#  17  Dividends Payable                                                     0 non-null      float64
#  18  Duefrom Related Parties Current                                       0 non-null      float64
#  19  Duefrom Related Parties Non Current                                   0 non-null      float64
#  20  Dueto Related Parties Current                                         0 non-null      float64
#  21  Dueto Related Parties Non Current                                     0 non-null      float64
#  22  Employee Benefits                                                     0 non-null      float64
#  23  Financial Assets                                                      0 non-null      float64
#  24  Financial Assets Designatedas Fair Value Through Profitor Loss Total  0 non-null      float64
#  25  Finished Goods                                                        273 non-null    float64
#  26  Foreign Currency Translation Adjustments                              0 non-null      float64
#  27  Goodwill                                                              0 non-null      float64
#  28  Goodwill And Other Intangible Assets                                  0 non-null      float64
#  29  Gross Accounts Receivable                                             0 non-null      float64
#  30  Hedging Assets Current                                                0 non-null      float64
#  31  Held To Maturity Securities                                           0 non-null      float64
#  32  Income Tax Payable                                                    92 non-null     float64
#  33  Interest Payable                                                      0 non-null      float64
#  34  Inventories Adjustments Allowances                                    0 non-null      float64
#  35  Investment Properties                                                 0 non-null      float64
#  36  Investments In Other Ventures Under Equity Method                     0 non-null      float64
#  37  Investmentsin Associatesat Cost                                       0 non-null      float64
#  38  Investmentsin Joint Venturesat Cost                                   0 non-null      float64
#  39  Investmentsin Subsidiariesat Cost                                     0 non-null      float64
#  40  Land And Improvements                                                 92 non-null     float64
#  41  Leases                                                                92 non-null     float64
#  42  Liabilities Heldfor Sale Non Current                                  0 non-null      float64
#  43  Line Of Credit                                                        0 non-null      float64
#  44  Loans Receivable                                                      0 non-null      float64
#  45  Long Term Capital Lease Obligation                                    92 non-null     float64
#  46  Long Term Equity Investment                                           0 non-null      float64
#  47  Long Term Provisions                                                  0 non-null      float64
#  48  Machinery Furniture Equipment                                         92 non-null     float64
#  49  Minimum Pension Liabilities                                           0 non-null      float64
#  50  Minority Interest                                                     0 non-null      float64
#  51  Non Current Accounts Receivable                                       0 non-null      float64
#  52  Non Current Accrued Expenses                                          0 non-null      float64
#  53  Non Current Deferred Assets                                           92 non-null     float64
#  54  Non Current Deferred Liabilities                                      0 non-null      float64
#  55  Non Current Deferred Revenue                                          0 non-null      float64
#  56  Non Current Deferred Taxes Assets                                     92 non-null     float64
#  57  Non Current Deferred Taxes Liabilities                                0 non-null      float64
#  58  Non Current Note Receivables                                          0 non-null      float64
#  59  Non Current Pension And Other Postretirement Benefit Plans            0 non-null      float64
#  60  Non Current Prepaid Assets                                            0 non-null      float64
#  61  Notes Receivable                                                      0 non-null      float64
#  62  Other Equity Interest                                                 0 non-null      float64
#  63  Other Intangible Assets                                               0 non-null      float64
#  64  Other Inventories                                                     0 non-null      float64
#  65  Other Investments                                                     92 non-null     float64
#  66  Other Payable                                                         0 non-null      float64
#  67  Other Properties                                                      92 non-null     float64
#  68  Pensionand Other Post Retirement Benefit Plans Current                0 non-null      float64
#  69  Preferred Securities Outside Stock Equity                             0 non-null      float64
#  70  Preferred Shares Number                                               0 non-null      float64
#  71  Preferred Stock                                                       0 non-null      float64
#  72  Preferred Stock Equity                                                0 non-null      float64
#  73  Prepaid Assets                                                        0 non-null      float64
#  74  Properties                                                            92 non-null     float64
#  75  Raw Materials                                                         273 non-null    float64
#  76  Receivables Adjustments Allowances                                    0 non-null      float64
#  77  Restricted Cash                                                       0 non-null      float64
#  78  Taxes Receivable                                                      0 non-null      float64
#  79  Total Tax Payable                                                     92 non-null     float64
#  80  Tradeand Other Payables Non Current                                   92 non-null     float64
#  81  Trading Securities                                                    0 non-null      float64
#  82  Treasury Shares Number                                                184 non-null    float64
#  83  Treasury Stock                                                        0 non-null      float64
#  84  Unrealized Gain Loss                                                  0 non-null      float64
#  85  Work In Process                                                       0 non-null      float64
# dtypes: float64(86)
# memory usage: 434.3 KB

# %%
try:
    # Filtramos solamente los nuevos registros
    df_incremental = bigquery.select_for_incremental(id='id', table=table_conca_to_save, new_df=pivoted_df)

    if not df_incremental.empty:
        # Guardamos los datos en Bigquery
        bigquery.save_dataframe(df_incremental, project, dataset_to_save, table_to_save, if_exists='append', schema=None)
        print(f'New records loaded')
    else:
        print('No new records to load.')

# En el caso de no tener datos en Bigquery, guardamos todo el df
except Exception as e:
    bigquery.save_dataframe(df_incremental, project, dataset_to_save, table_to_save, if_exists='replace', schema=None)
    print('New data persisted')
    print(f'Exception encountered: {e}')
# Out:
# No new records to load.
